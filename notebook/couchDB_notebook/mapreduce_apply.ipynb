# %% [markdown]
# https://docs.couchbase.com/server/current/learn/views/views-writing.html
#
# https://couchdb-python.readthedocs.io/en/latest/client.html#database
# https://docs.couchbase.com/server/current/learn/views/views-writing.html
# https://www.joshmorony.com/couchdb-pouchdb-and-ionic-2-querying-data-with-mapreduce/
# https://blog.pablobm.com/2019/07/18/map-reduce-with-couchdb-a-visual-primer.html

# %% [markdown]
# Map candidates
# - Time
# - Location
# - Happiness score (see the happy vs unhappy)
# - Behaviours labels (6)
# - User ID
# - (opt) tokens

# %%
import couchdb
from dotenv import load_dotenv
import os

# %%
load_dotenv("../key.env")
SECRET_KEY = os.environ.get("SECRET_KEY")

# %%
couch = couchdb.Server(f'http://{SECRET_KEY}@localhost:5984/')
db = couch['twitter_loc']

# map_fun = '''function(d) {
#     const [date, time] = doc.doc.created_at.split("T");
#     const [year, month, day] = date.split("-");
#     emit(doc.doc.created_at);
# }'''
map_fun = '''function(d) {
    emit(d.id, d.key);
}'''
db.query(map_fun)
# Out:
# <ViewResults <TemporaryView 'function(d) {\n    emit(d.id, d.key);\n}' None> {}>

# %%
for dbname in couch:
    print(dbname)
# Out:
# python-tests
# test1
# twitter_loc

# %%
view = db.view('theview')

# %%
couch = couchdb.Server(f'http://{SECRET_KEY}@localhost:5984/')
db = couch['twitter_loc']
for doc in db.find({'selector': {'type': 'post'}}):
    # process your doc
    print(doc)

# %% [markdown]
# https://gist.github.com/marians/8e41fc817f04de7c4a70

# %%
for doc in db.find({'selector': {"post_id": "1491633713435738113", "author_id":"1446643791956348932"}}):
     print(doc)
# Out:
# <Document '9da597b8f82c31a94a0abbb389000f3d'@'1-59e190cf982fdae8320d01a9b22ece67' {'post_id': '1491633713435738113', 'author_id': '1446643791956348932', 'created_at': '2022-02-10T04:42:45.000Z', 'content': '@Felon82 He swallows', 'location': {'place_id': '0073b76548e5984f'}, 'language': 'en', 'sentiment': 0.0, 'tags': [], 'tokens': ['swallows']}>

# %%
for item in db.view('design_doc/view_name', limit=100):
    print(item.key, item.id, item.value)

# %%
for item in db.view('design_doc/view_name', descending=True):
    print(item.key, item.id, item.value)

# %%
for item in db.view('design_doc/view_name', group=True, group_level=1):
    print(item.key, item.value)

# %%
for item in db.view('design_doc/view_name', key="my_key"):
    print(item.key, item.id, item.value)

# %%
for item in db.view('design_doc/view_name', startkey="startkey", endkey="endkey"):
    print(item.key, item.id, item.value)

# %%
idx = db.index()
list(idx)
# Out:
# [{'ddoc': None,
#   'name': '_all_docs',
#   'type': 'special',
#   'def': {'fields': [{'_id': 'asc'}]}}]

# %%
for id in db:
    print(db[id]["created_at"])
# Out:
# 2022-02-10T04:42:45.000Z
# 2022-02-10T05:46:31.000Z
# 2022-02-10T00:07:21.000Z
# 2022-02-10T00:06:27.000Z
# 2022-02-10T00:09:58.000Z
# 2022-02-10T00:11:24.000Z
# 2022-02-10T02:12:58.000Z
# 2022-02-10T02:15:33.000Z
# 2022-02-10T14:44:33.000Z
# 2022-02-10T01:23:00.000Z
# 2022-02-10T00:34:11.000Z
# 2022-02-10T00:38:32.000Z
# 2022-02-10T00:34:33.000Z
# 2022-02-10T00:45:39.000Z
# 2022-02-10T00:34:42.000Z
# 2022-02-10T00:53:50.000Z
# 2022-02-10T00:34:48.000Z
# 2022-02-10T00:35:05.000Z
# 2022-02-10T00:36:46.000Z
# 2022-02-10T00:36:59.000Z
# 2022-02-10T00:35:05.000Z
# 2022-02-10T00:35:24.000Z
# 2022-02-10T00:35:31.000Z
# 2022-02-10T00:35:34.000Z
# 2022-02-10T22:57:14.000Z
# 2022-02-10T22:59:37.000Z
# 2022-02-10T23:00:22.000Z
# 2022-02-10T23:01:10.000Z
# 2022-02-10T00:35:37.000Z
# 2022-02-10T02:29:55.000Z
# 2022-02-10T00:35:47.000Z
# 2022-02-10T01:52:44.000Z
# 2022-02-10T00:36:13.000Z
# 2022-02-10T00:36:25.000Z
# 2022-02-10T00:36:26.000Z
# 2022-02-10T03:13:35.000Z
# 2022-02-10T08:33:04.000Z
# 2022-02-10T09:24:10.000Z
# 2022-02-10T00:37:01.000Z
# 2022-02-10T00:37:05.000Z
# 2022-02-10T05:41:25.000Z
# 2022-02-10T00:37:34.000Z
# 2022-02-10T00:37:51.000Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 for id in db:
# ----> 2     print(db[id]["created_at"])
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/client.py:435, in Database.__getitem__(self, id)
#     428 def __getitem__(self, id):
#     429     """Return the document with the specified ID.
#     430
#     431     :param id: the document ID
#     432     :return: a `Row` object representing the requested document
#     433     :rtype: `Document`
#     434     """
# --> 435     _, _, data = _doc_resource(self.resource, id).get_json()
#     436     return Document(data)
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/http.py:570, in Resource.get_json(self, path, headers, **params)
#     569 def get_json(self, path=None, headers=None, **params):
# --> 570     return self._request_json('GET', path, headers=headers, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/http.py:595, in Resource._request_json(self, method, path, body, headers, **params)
#     594 def _request_json(self, method, path=None, body=None, headers=None, **params):
# --> 595     status, headers, data = self._request(method, path, body=body,
#     596                                           headers=headers, **params)
#     597     if 'application/json' in headers.get('content-type', ''):
#     598         data = json.decode(data.read().decode('utf-8'))
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/http.py:590, in Resource._request(self, method, path, body, headers, **params)
#     588 else:
#     589     url = urljoin(self.url, **params)
# --> 590 return self.session.request(method, url, body=body,
#     591                             headers=all_headers,
#     592                             credentials=self.credentials)
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/http.py:398, in Session.request(self, method, url, body, headers, credentials, num_redirects)
#     396 # Buffer small non-JSON response bodies
#     397 elif int(resp.getheader('content-length', sys.maxsize)) < CHUNK_SIZE:
# --> 398     data = resp.read()
#     399     self.connection_pool.release(url, conn)
#     401 # For large or chunked response bodies, do not buffer the full body,
#     402 # and instead return a minimal file-like object
#     403 else:
#
# File ~/miniconda3/lib/python3.9/http/client.py:481, in HTTPResponse.read(self, amt)
#     479         raise
#     480     self.length = 0
# --> 481 self._close_conn()        # we read everything
#     482 return s
#
# KeyboardInterrupt:

# %%
for row in db.query(map_fun, descending=True):
    print(row.key)

# %%
for row in db.query(map_fun, key='John Doe'):
    print(row.key)

# %% [markdown]
# ### Add data

# %%
db['gotham'] = dict(type='City', name='Gotham City')

# %%
for row in db.view('_all_docs'):
    print(row.id)
# Out:
# gotham
# johndoe
# maryjane

# %%
# db['johndoe'] = dict(type='Person', name='John Doe')
# db['maryjane'] = dict(type='Person', name='Mary Jane')
# db['gotham'] = dict(type='City', name='Gotham City')
map_fun = '''function(doc) {
    emit([doc.type, doc.name], doc.name);
}'''
results = db.query(map_fun)
results
# Out:
# <ViewResults <TemporaryView 'function(doc) {\n    emit([doc.type, doc.name], doc.name);\n}' None> {}>

# %%
len(results)

# %%
people = results[['Person']:['Person','ZZZZ']]
for person in people:
    print(person.value)
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 people = results[['Person']:['Person','ZZZZ']]
# ----> 2 for person in people:
#       3     print(person.value)
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/client.py:1358, in ViewResults.__iter__(self)
#    1357 def __iter__(self):
# -> 1358     return iter(self.rows)
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/client.py:1378, in ViewResults.rows(self)
#    1373 """The list of rows returned by the view.
#    1374
#    1375 :rtype: `list`
#    1376 """
#    1377 if self._rows is None:
# -> 1378     self._fetch()
#    1379 return self._rows
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/client.py:1364, in ViewResults._fetch(self)
#    1363 def _fetch(self):
# -> 1364     data = self.view._exec(self.options)
#    1365     wrapper = self.view.wrapper or Row
#    1366     self._rows = [wrapper(row) for row in data['rows']]
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/client.py:1262, in TemporaryView._exec(self, options)
#    1260     body['keys'] = options.pop('keys')
#    1261 content = json.encode(body).encode('utf-8')
# -> 1262 _, _, data = self.resource.post_json(body=content, headers={
#    1263     'Content-Type': 'application/json'
#    1264 }, **_encode_view_options(options))
#    1265 return data
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/http.py:573, in Resource.post_json(self, path, body, headers, **params)
#     572 def post_json(self, path=None, body=None, headers=None, **params):
# --> 573     return self._request_json('POST', path, body=body, headers=headers,
#     574                               **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/http.py:595, in Resource._request_json(self, method, path, body, headers, **params)
#     594 def _request_json(self, method, path=None, body=None, headers=None, **params):
# --> 595     status, headers, data = self._request(method, path, body=body,
#     596                                           headers=headers, **params)
#     597     if 'application/json' in headers.get('content-type', ''):
#     598         data = json.decode(data.read().decode('utf-8'))
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/http.py:590, in Resource._request(self, method, path, body, headers, **params)
#     588 else:
#     589     url = urljoin(self.url, **params)
# --> 590 return self.session.request(method, url, body=body,
#     591                             headers=all_headers,
#     592                             credentials=self.credentials)
#
# File ~/miniconda3/lib/python3.9/site-packages/couchdb/http.py:429, in Session.request(self, method, url, body, headers, credentials, num_redirects)
#     427         raise PreconditionFailed(error)
#     428     else:
# --> 429         raise ServerError((status, error))
#     431 # Store cachable responses
#     432 if not streamed and method == 'GET' and 'etag' in resp.msg:
#
# ServerError: (410, ('gone', 'Temporary views are not supported in CouchDB'))

# %%
function (document) {
  const [date, time] = document.visitedAt.split("T");
  const [year, month, day] = date.split("-");
  emit([year, month, day], 1);
}
