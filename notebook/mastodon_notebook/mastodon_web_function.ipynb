# %%
from mastodon import Mastodon, StreamListener
import yaml

# %%
with open("./api.yaml", encoding="UTF-8") as f:
    cfg = yaml.load(f, Loader=yaml.FullLoader)
    m = Mastodon(
        api_base_url=f"https://mastodon.au",
        access_token=cfg["MASTODON_ACCESS_TOKEN"],
    )
m.timeline_public() #limit=10000, only_media=True)
# Out:
# [{'id': 110367216994622117,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 42, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://mas.to/users/dmacphee/statuses/110367216911968402',
#   'url': 'https://mas.to/@dmacphee/110367216911968402',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p>An interesting essay. Not sure how realistic it would be politically though. <br><a href="https://mas.to/tags/cdnpoli" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>cdnpoli</span></a> <a href="https://mas.to/tags/canpoli" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>canpoli</span></a> <a href="https://mas.to/tags/canada" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>canada</span></a> <a href="https://mas.to/tags/taxes" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>taxes</span></a> </p><p>Taxing the wealthy to the hilt would make us all much better off. <br><a href="https://theconversation.com/taxing-the-wealthy-to-the-hilt-would-make-us-all-much-better-off-203814" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">theconversation.com/taxing-the</span><span class="invisible">-wealthy-to-the-hilt-would-make-us-all-much-better-off-203814</span></a></p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109360430124026331,
#    'username': 'dmacphee',
#    'acct': 'dmacphee@mas.to',
#    'display_name': 'Daniel MacPhee 🥼🔬🧬🧫🇨🇦',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 11, 5, 0, 0, tzinfo=tzutc()),
#    'note': '<p>Professor of Reproductive Sciences. Saskatoon, Saskatchewan. Interested in evidence-based decision making, science communication, reproductive biology. Opinions my own. <br><a href="https://mas.to/tags/ReproSci" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>ReproSci</span></a> <a href="https://mas.to/tags/ReproBio" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>ReproBio</span></a> <a href="https://mas.to/tags/Science" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Science</span></a> <a href="https://mas.to/tags/Reproverse" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Reproverse</span></a> <a href="https://mas.to/tags/Reproduction" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Reproduction</span></a> <a href="https://mas.to/tags/Scicomm" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Scicomm</span></a> <a href="https://mas.to/tags/fedi22" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>fedi22</span></a> <a href="https://mas.to/tags/PretermBirth" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>PretermBirth</span></a></p>',
#    'url': 'https://mas.to/@dmacphee',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/360/430/124/026/331/original/257f4b3d001c3fa9.png',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/360/430/124/026/331/original/257f4b3d001c3fa9.png',
#    'header': 'https://mastodon.au/headers/original/missing.png',
#    'header_static': 'https://mastodon.au/headers/original/missing.png',
#    'followers_count': 509,
#    'following_count': 346,
#    'statuses_count': 4508,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'Website',
#      'value': '<a href="https://wcvm.usask.ca/departments/biomedical/biomedical-people/daniel-macphee.php" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">wcvm.usask.ca/departments/biom</span><span class="invisible">edical/biomedical-people/daniel-macphee.php</span></a>',
#      'verified_at': None},
#     {'name': 'Google Scholar',
#      'value': '<a href="https://scholar.google.com/citations?user=j60eAK8AAAAJ" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">scholar.google.com/citations?u</span><span class="invisible">ser=j60eAK8AAAAJ</span></a>',
#      'verified_at': None},
#     {'name': 'ORCID ID#',
#      'value': '<a href="https://orcid.org/0000-0001-5721-6185" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">orcid.org/0000-0001-5721-6185</span><span class="invisible"></span></a>',
#      'verified_at': None}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [{'name': 'taxes', 'url': 'https://mastodon.au/tags/taxes'},
#    {'name': 'canada', 'url': 'https://mastodon.au/tags/canada'},
#    {'name': 'canpoli', 'url': 'https://mastodon.au/tags/canpoli'},
#    {'name': 'cdnpoli', 'url': 'https://mastodon.au/tags/cdnpoli'}],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367216453474450,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 32, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://press.coop/users/timesofindia/statuses/110367216299628906',
#   'url': 'https://press.coop/@timesofindia/110367216299628906',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p><a href="https://press.coop/tags/WATCH" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>WATCH</span></a> | Karnataka: Congress leaders arrive for CLP meeting at a hotel in Bengaluru</p><p><a href="https://press.coop/tags/KarnatakaElection2023" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>KarnatakaElection2023</span></a>  <a href="https://press.coop/tags/press" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>press</span></a></p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109985812464786319,
#    'username': 'timesofindia',
#    'acct': 'timesofindia@press.coop',
#    'display_name': 'The Times Of India :press:',
#    'locked': False,
#    'bot': True,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2010, 4, 19, 0, 0, tzinfo=tzutc()),
#    'note': '<p>News. Views. Analysis. Conversations. India’s No.1 digital news destination, world’s largest-selling English newspaper - A Times Internet Limited Product</p><p>( account mirrored by <a href="https://press.coop" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">press.coop</span><span class="invisible"></span></a> )</p>',
#    'url': 'https://press.coop/@timesofindia',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/985/812/464/786/319/original/cf261e85c33c0d69.png',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/985/812/464/786/319/original/cf261e85c33c0d69.png',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/109/985/812/464/786/319/original/7f68327dd2c991b7.jpeg',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/109/985/812/464/786/319/original/7f68327dd2c991b7.jpeg',
#    'followers_count': 25,
#    'following_count': 0,
#    'statuses_count': 2853,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [{'shortcode': 'press',
#      'url': 'https://o.mastodon.au/cache/custom_emojis/images/000/099/369/original/8ef14563dc76f1f2.png',
#      'static_url': 'https://o.mastodon.au/cache/custom_emojis/images/000/099/369/static/8ef14563dc76f1f2.png',
#      'visible_in_picker': True}],
#    'fields': [{'name': 'Twitter',
#      'value': '<a href="https://hello.coop/Twttr/timesofindia" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">hello.coop/Twttr/timesofindia</span><span class="invisible"></span></a>',
#      'verified_at': '2023-03-29T10:53:42.012+00:00'},
#     {'name': 'Website',
#      'value': '<a href="http://toi.in/BJa_yb63" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">http://</span><span class="">toi.in/BJa_yb63</span><span class="invisible"></span></a>',
#      'verified_at': None}]},
#   'media_attachments': [{'id': 110367216406720769,
#     'type': 'image',
#     'url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/216/406/720/769/original/cf14e2870a47b00e.jpg',
#     'preview_url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/216/406/720/769/small/cf14e2870a47b00e.jpg',
#     'remote_url': 'https://pbs.twimg.com/amplify_video_thumb/1657735773754654720/img/VxFdllzBuVfmS94n.jpg',
#     'preview_remote_url': None,
#     'text_url': None,
#     'meta': {'original': {'width': 480,
#       'height': 270,
#       'size': '480x270',
#       'aspect': 1.7777777777777777},
#      'small': {'width': 480,
#       'height': 270,
#       'size': '480x270',
#       'aspect': 1.7777777777777777}},
#     'description': None,
#     'blurhash': 'UTI=0:R:4:xt9}e,xqxZ4moexuE3s8SiaynN'}],
#   'mentions': [],
#   'tags': [{'name': 'watch', 'url': 'https://mastodon.au/tags/watch'},
#    {'name': 'karnatakaelection2023',
#     'url': 'https://mastodon.au/tags/karnatakaelection2023'},
#    {'name': 'press', 'url': 'https://mastodon.au/tags/press'}],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367216398473769,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 31, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://sigmoid.social/users/TedUnderwood/statuses/110367216175310482',
#   'url': 'https://sigmoid.social/@TedUnderwood/110367216175310482',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p>My salt-of-the-earth grandparents used to warn me there was more to life than “book learning,” and now I want to repeat that advice to people who are worried <a href="https://sigmoid.social/tags/AI" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>AI</span></a> will take over. Sign manipulation is great. But there’s also a real world out there that doesn’t align w/ our sign systems.</p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109365223546960494,
#    'username': 'TedUnderwood',
#    'acct': 'TedUnderwood@sigmoid.social',
#    'display_name': 'Ted Underwood',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 11, 8, 0, 0, tzinfo=tzutc()),
#    'note': '<p>I use machine learning to study cultural history at the School of Information Sciences, UIUC. Also <a href="https://sigmoid.social/tags/generativeAI" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>generativeAI</span></a>, <a href="https://sigmoid.social/tags/digitalhumanities" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>digitalhumanities</span></a>, <a href="https://sigmoid.social/tags/sciencefiction" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>sciencefiction</span></a>, <a href="https://sigmoid.social/tags/computational" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>computational</span></a> <a href="https://sigmoid.social/tags/socialscience" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>socialscience</span></a>. Author of Distant Horizons (Chicago, 2019). <a href="https://sigmoid.social/tags/tfr" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>tfr</span></a> <a href="https://sigmoid.social/tags/fedi22" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>fedi22</span></a></p>',
#    'url': 'https://sigmoid.social/@TedUnderwood',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/365/223/546/960/494/original/ba9be55a2ca4023d.png',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/365/223/546/960/494/original/ba9be55a2ca4023d.png',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/109/365/223/546/960/494/original/feb247ff8c0b3426.png',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/109/365/223/546/960/494/original/feb247ff8c0b3426.png',
#    'followers_count': 3617,
#    'following_count': 1146,
#    'statuses_count': 2959,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'book',
#      'value': '<a href="https://press.uchicago.edu/ucp/books/book/chicago/D/bo35853783.html" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">press.uchicago.edu/ucp/books/b</span><span class="invisible">ook/chicago/D/bo35853783.html</span></a>',
#      'verified_at': None},
#     {'name': 'blog',
#      'value': '<a href="https://tedunderwood.com/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">tedunderwood.com/</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'GitHub',
#      'value': '<a href="https://github.com/tedunderwood" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">github.com/tedunderwood</span><span class="invisible"></span></a>',
#      'verified_at': '2023-03-26T21:52:02.431+00:00'}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [{'name': 'ai', 'url': 'https://mastodon.au/tags/ai'}],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367216372488121,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 29, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://social.ridetrans.it/users/dx/statuses/110367216051419146',
#   'url': 'https://social.ridetrans.it/@dx/110367216051419146',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p>No gods<br>No masters<br>No cookies</p><p>Reject all</p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109316588472815581,
#    'username': 'dx',
#    'acct': 'dx@social.ridetrans.it',
#    'display_name': '🚲',
#    'locked': True,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 11, 1, 0, 0, tzinfo=tzutc()),
#    'note': "<p>Mostly bikes. I'm into compact towns and cities where you don't need to own a car and heavy economic board games. Machine learning stuff is my day job.</p><p>The world is on fire and we should try to save some of it before there's nothing but ashes.</p><p> 🚲 🚶 🚉 🤖 🧗🏻 🎲, \U0001d2d1\U0001d2cc</p>",
#    'url': 'https://social.ridetrans.it/@dx',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/316/588/472/815/581/original/ade6e18c35478c8b.gif',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/316/588/472/815/581/static/ade6e18c35478c8b.png',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/109/316/588/472/815/581/original/4173bf0c2e596719.jpg',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/109/316/588/472/815/581/original/4173bf0c2e596719.jpg',
#    'followers_count': 491,
#    'following_count': 273,
#    'statuses_count': 2683,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'Live',
#      'value': 'Vancouver Island',
#      'verified_at': None},
#     {'name': 'Laugh', 'value': 'Deadpan absurdism', 'verified_at': None},
#     {'name': 'Love', 'value': 'Behind closed doors', 'verified_at': None}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367216098570510,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 26, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://theblower.au/users/jonlawrence/statuses/110367215882900522',
#   'url': 'https://theblower.au/@jonlawrence/110367215882900522',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p>Snug</p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109373011576577045,
#    'username': 'jonlawrence',
#    'acct': 'jonlawrence@theblower.au',
#    'display_name': 'Jonny Ell',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 11, 14, 0, 0, tzinfo=tzutc()),
#    'note': "<p>Reformed Canberran. Telemark skier. Rory's housemate (that's him in the photo)</p>",
#    'url': 'https://theblower.au/@jonlawrence',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/373/011/576/577/045/original/2d8691ddeafc342d.png',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/373/011/576/577/045/original/2d8691ddeafc342d.png',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/109/373/011/576/577/045/original/4156b3b047e4009d.png',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/109/373/011/576/577/045/original/4156b3b047e4009d.png',
#    'followers_count': 140,
#    'following_count': 245,
#    'statuses_count': 884,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'Location',
#      'value': '<a href="https://theblower.au/tags/Canberra" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Canberra</span></a>, <a href="https://theblower.au/tags/Ngunnawal" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Ngunnawal</span></a>, <a href="https://theblower.au/tags/Ngambri" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Ngambri</span></a>, <a href="https://theblower.au/tags/Kamberri" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Kamberri</span></a> country',
#      'verified_at': None},
#     {'name': 'Interests',
#      'value': '<a href="https://theblower.au/tags/Dogs" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Dogs</span></a> <a href="https://theblower.au/tags/MentalHealth" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>MentalHealth</span></a> <a href="https://theblower.au/tags/UrbanPlanning" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>UrbanPlanning</span></a> <a href="https://theblower.au/tags/Socceroos" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Socceroos</span></a> <a href="https://theblower.au/tags/Swans" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Swans</span></a> <a href="https://theblower.au/tags/Politics" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Politics</span></a> <a href="https://theblower.au/tags/History" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>History</span></a>',
#      'verified_at': None}]},
#   'media_attachments': [{'id': 110367215964792131,
#     'type': 'image',
#     'url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/215/964/792/131/original/e5b8111b2c61f82f.jpg',
#     'preview_url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/215/964/792/131/small/e5b8111b2c61f82f.jpg',
#     'remote_url': 'https://static.theblower.au/media_attachments/files/110/367/212/296/641/585/original/b7ab93e6fc4ac38f.jpg',
#     'preview_remote_url': None,
#     'text_url': None,
#     'meta': {'original': {'width': 1566,
#       'height': 1324,
#       'size': '1566x1324',
#       'aspect': 1.1827794561933536},
#      'small': {'width': 522,
#       'height': 441,
#       'size': '522x441',
#       'aspect': 1.183673469387755}},
#     'description': 'cute dog snuggled up on the couch with his left ear raised',
#     'blurhash': 'UTC$Ab~AxEt6589uNHazI;f6xZNHxZxZoLt6'}],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367216096760983,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 20, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'it',
#   'uri': 'https://musician.social/users/wiseman/statuses/110367215465242153',
#   'url': 'https://musician.social/@wiseman/110367215465242153',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p>Happy birthday Ian Astbury (61) <br><a href="https://i.devol.it/ZCOSPtyZAPA?t=32" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">i.devol.it/ZCOSPtyZAPA?t=32</span><span class="invisible"></span></a> <br><a href="https://musician.social/tags/thecult" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>thecult</span></a> <a href="https://musician.social/tags/birthday" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>birthday</span></a> <a href="https://musician.social/tags/ianastbury" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>ianastbury</span></a> <a href="https://musician.social/tags/music" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>music</span></a> <a href="https://musician.social/tags/musica" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>musica</span></a> <a href="https://musician.social/tags/postpunk" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>postpunk</span></a> <a href="https://musician.social/tags/newwave" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>newwave</span></a> <a href="https://musician.social/tags/rock" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>rock</span></a> <a href="https://musician.social/tags/alternativerock" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>alternativerock</span></a> <a href="https://musician.social/tags/80s" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>80s</span></a></p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 110007052539227694,
#    'username': 'wiseman',
#    'acct': 'wiseman@musician.social',
#    'display_name': 'Wise Man',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2023, 3, 10, 0, 0, tzinfo=tzutc()),
#    'note': '<p>Music lover, drummer, composer from Italy.<br>Post-punk, new wave and alternative rock lover.<br>Here to learn about new music but also to have a chat.<br>He/Him</p>',
#    'url': 'https://musician.social/@wiseman',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/110/007/052/539/227/694/original/52afe0ec7ca66326.jpg',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/110/007/052/539/227/694/original/52afe0ec7ca66326.jpg',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/110/007/052/539/227/694/original/3c235a142fae610f.webp',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/110/007/052/539/227/694/original/3c235a142fae610f.webp',
#    'followers_count': 47,
#    'following_count': 29,
#    'statuses_count': 530,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': []},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [{'name': 'thecult', 'url': 'https://mastodon.au/tags/thecult'},
#    {'name': 'birthday', 'url': 'https://mastodon.au/tags/birthday'},
#    {'name': 'ianastbury', 'url': 'https://mastodon.au/tags/ianastbury'},
#    {'name': 'music', 'url': 'https://mastodon.au/tags/music'},
#    {'name': 'musica', 'url': 'https://mastodon.au/tags/musica'},
#    {'name': 'postpunk', 'url': 'https://mastodon.au/tags/postpunk'},
#    {'name': 'newwave', 'url': 'https://mastodon.au/tags/newwave'},
#    {'name': 'rock', 'url': 'https://mastodon.au/tags/rock'},
#    {'name': 'alternativerock',
#     'url': 'https://mastodon.au/tags/alternativerock'},
#    {'name': '80s', 'url': 'https://mastodon.au/tags/80s'}],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367215851517896,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 18, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://wandering.shop/users/thorncoyle/statuses/110367215383570529',
#   'url': 'https://wandering.shop/@thorncoyle/110367215383570529',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p>Have a gloriously gorgeous day! </p><p><a href="https://wandering.shop/tags/rhododendron" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>rhododendron</span></a> <a href="https://wandering.shop/tags/photography" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>photography</span></a>  <a href="https://wandering.shop/tags/flowers" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>flowers</span></a> <a href="https://wandering.shop/tags/sunday" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>sunday</span></a></p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109362840908152824,
#    'username': 'thorncoyle',
#    'acct': 'thorncoyle@wandering.shop',
#    'display_name': 'T. Thorn Coyle 🖤',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 11, 2, 0, 0, tzinfo=tzutc()),
#    'note': '<p>A professional writer and amateur photographer. <br>I take a lot of walks and talk to squirrels, trees, and crows. I believe in the power of mutual aid to help build strong communities. \u2029<br>I write books. A lot of books. Like, really a lot of books.\u2028\u2028<br>Magic is real. Justice is worth fighting for. Many Gods. No Masters.\u2029Queer with a chronic illness. They/Them</p><p><a href="https://wandering.shop/tags/AmWriting" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>AmWriting</span></a> <a href="https://wandering.shop/tags/IndieAuthors" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>IndieAuthors</span></a> <a href="https://wandering.shop/tags/Writing" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Writing</span></a> <a href="https://wandering.shop/tags/SFF" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>SFF</span></a> <a href="https://wandering.shop/tags/SocialJustice" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>SocialJustice</span></a> <a href="https://wandering.shop/tags/Magic" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Magic</span></a> <a href="https://wandering.shop/tags/SpiritualPractice" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>SpiritualPractice</span></a> <a href="https://wandering.shop/tags/bookstodon" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>bookstodon</span></a> <a href="https://wandering.shop/tags/photography" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>photography</span></a></p>',
#    'url': 'https://wandering.shop/@thorncoyle',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/362/840/908/152/824/original/3d10bfc7e7b2e98e.png',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/362/840/908/152/824/original/3d10bfc7e7b2e98e.png',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/109/362/840/908/152/824/original/6e24db85c478aef6.png',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/109/362/840/908/152/824/original/6e24db85c478aef6.png',
#    'followers_count': 916,
#    'following_count': 692,
#    'statuses_count': 1386,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'Website',
#      'value': '<a href="https://www.thorncoyle.com" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="">thorncoyle.com</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Weekly Musings',
#      'value': '<a href="https://tthorncoyle.substack.com" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">tthorncoyle.substack.com</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Patreon',
#      'value': '<a href="https://www.patreon.com/ThornCoyle" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="">patreon.com/ThornCoyle</span><span class="invisible"></span></a>',
#      'verified_at': None}]},
#   'media_attachments': [{'id': 110367215778772156,
#     'type': 'image',
#     'url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/215/778/772/156/original/78d78602d9f1cf3f.jpeg',
#     'preview_url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/215/778/772/156/small/78d78602d9f1cf3f.jpeg',
#     'remote_url': 'https://stockroom.wandering.shop/media_attachments/files/110/367/212/410/488/998/original/0de65df93506f472.jpeg',
#     'preview_remote_url': None,
#     'text_url': None,
#     'meta': {'focus': {'x': 0.0, 'y': 0.0},
#      'original': {'width': 1280,
#       'height': 1280,
#       'size': '1280x1280',
#       'aspect': 1.0},
#      'small': {'width': 480, 'height': 480, 'size': '480x480', 'aspect': 1.0}},
#     'description': 'A round cluster of hot pink rhododendron flowers.',
#     'blurhash': 'UdILgDNY1qsDV@bHj[oM1:afsXj]jcjbW.ay'}],
#   'mentions': [],
#   'tags': [{'name': 'rhododendron',
#     'url': 'https://mastodon.au/tags/rhododendron'},
#    {'name': 'photography', 'url': 'https://mastodon.au/tags/photography'},
#    {'name': 'flowers', 'url': 'https://mastodon.au/tags/flowers'},
#    {'name': 'sunday', 'url': 'https://mastodon.au/tags/sunday'}],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367215437017914,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 14, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://mastodon.world/users/backpackandsnorkel/statuses/110367215061608986',
#   'url': 'https://mastodon.world/@backpackandsnorkel/110367215061608986',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p><a href="https://mastodon.world/tags/Otumuheke" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Otumuheke</span></a> Stream in <a href="https://mastodon.world/tags/Taupo" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Taupo</span></a> in New Zealand is a historical <a href="https://mastodon.world/tags/M%C4%81ori" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Māori</span></a> bathing and meeting place where a small hot stream flows into the <a href="https://mastodon.world/tags/Waikato" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Waikato</span></a> River. A nice place to <a href="https://mastodon.world/tags/relax" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>relax</span></a> . <a href="https://mastodon.world/tags/NewZealand" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>NewZealand</span></a><br><a href="https://backpackandsnorkel.com/Taupo/#otumuheke" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">backpackandsnorkel.com/Taupo/#</span><span class="invisible">otumuheke</span></a></p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109390727877753477,
#    'username': 'backpackandsnorkel',
#    'acct': 'backpackandsnorkel@mastodon.world',
#    'display_name': 'Backpack and Snorkel',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 11, 23, 0, 0, tzinfo=tzutc()),
#    'note': '<p>We <a href="https://mastodon.world/tags/travel" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>travel</span></a> the <a href="https://mastodon.world/tags/world" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>world</span></a> and show you the best places to see and the best things to do. <br>With our <a href="https://mastodon.world/tags/backpack" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>backpack</span></a> and <a href="https://mastodon.world/tags/snorkel" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>snorkel</span></a> we do not just seek out <a href="https://mastodon.world/tags/whitesand" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>whitesand</span></a> <a href="https://mastodon.world/tags/beaches" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>beaches</span></a> and <a href="https://mastodon.world/tags/turquoisewater" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>turquoisewater</span></a> , but we <a href="https://mastodon.world/tags/hike" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>hike</span></a> <a href="https://mastodon.world/tags/mountains" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>mountains</span></a> and <a href="https://mastodon.world/tags/explore" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>explore</span></a> big and small <a href="https://mastodon.world/tags/cities" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>cities</span></a> <a href="https://mastodon.world/tags/worldwide" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>worldwide</span></a>. <br>Let us <a href="https://mastodon.world/tags/inspire" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>inspire</span></a> you to make memorable moments on <a href="https://mastodon.world/tags/relaxing" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>relaxing</span></a> <a href="https://mastodon.world/tags/vacations" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>vacations</span></a> .</p>',
#    'url': 'https://mastodon.world/@backpackandsnorkel',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/390/727/877/753/477/original/03f9f7f33cbd162b.jpg',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/390/727/877/753/477/original/03f9f7f33cbd162b.jpg',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/109/390/727/877/753/477/original/53891345f683661c.png',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/109/390/727/877/753/477/original/53891345f683661c.png',
#    'followers_count': 2297,
#    'following_count': 2614,
#    'statuses_count': 1390,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'Website',
#      'value': '<a href="https://backpackandsnorkel.com/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">backpackandsnorkel.com/</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'facebook',
#      'value': '<a href="https://www.facebook.com/BPaSnorkel" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="">facebook.com/BPaSnorkel</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'instagram',
#      'value': '<a href="https://www.instagram.com/backpack_and_snorkel/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">instagram.com/backpack_and_sno</span><span class="invisible">rkel/</span></a>',
#      'verified_at': None},
#     {'name': 'pinterest',
#      'value': '<a href="https://www.pinterest.com/backpackandsnorkel/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">pinterest.com/backpackandsnork</span><span class="invisible">el/</span></a>',
#      'verified_at': None}]},
#   'media_attachments': [{'id': 110367215288249063,
#     'type': 'image',
#     'url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/215/288/249/063/original/32031de91938dcc5.jpg',
#     'preview_url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/215/288/249/063/small/32031de91938dcc5.jpg',
#     'remote_url': 'https://s3.eu-central-2.wasabisys.com/mastodonworld/media_attachments/files/110/367/214/867/227/379/original/c5d9d4af6deb08d6.jpg',
#     'preview_remote_url': None,
#     'text_url': None,
#     'meta': {'original': {'width': 500,
#       'height': 376,
#       'size': '500x376',
#       'aspect': 1.3297872340425532},
#      'small': {'width': 500,
#       'height': 376,
#       'size': '500x376',
#       'aspect': 1.3297872340425532}},
#     'description': None,
#     'blurhash': 'UWGSfabbxVWW5]RioIbIx|ajkBoNtUWBt8Rj'}],
#   'mentions': [],
#   'tags': [{'name': 'otumuheke', 'url': 'https://mastodon.au/tags/otumuheke'},
#    {'name': 'taupo', 'url': 'https://mastodon.au/tags/taupo'},
#    {'name': 'maori', 'url': 'https://mastodon.au/tags/maori'},
#    {'name': 'waikato', 'url': 'https://mastodon.au/tags/waikato'},
#    {'name': 'relax', 'url': 'https://mastodon.au/tags/relax'},
#    {'name': 'newzealand', 'url': 'https://mastodon.au/tags/newzealand'}],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367215018651900,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 10, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'nl',
#   'uri': 'https://mastodon.nl/users/hvangalen/statuses/110367214836102355',
#   'url': 'https://mastodon.nl/@hvangalen/110367214836102355',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': "<p>Toch is het lastig, zo'n probleem met elektra.</p><p>Plots om 12u 's nachts begon het achter elkaar uit te vallen (tot de slechte groep werd gevonden). Nu denk ik de boosdoener gevonden te hebben en staat alles weer aan, maar hoe ik zeker kan weten, is echt een kwestie van (lange) tijd.</p><p>De eerste keer dat dit gebeurde was een paar weken geleden na het opknappen van de badkamer (en ik toen onterecht twijfelde aan de aansluiting van het licht daar). Daarna weken geen probleem gehad tot vannacht...</p>",
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109377379742194038,
#    'username': 'hvangalen',
#    'acct': 'hvangalen@mastodon.nl',
#    'display_name': 'hugovangalen  🤖 🕹️ 😼',
#    'locked': False,
#    'bot': False,
#    'discoverable': False,
#    'group': False,
#    'created_at': datetime.datetime(2022, 4, 26, 0, 0, tzinfo=tzutc()),
#    'note': '<p>coder • (retro)techy • 3d printing • electronics • linux<br>• casual gamer</p><p>I make &amp; break stuff</p><p>toots are in English and Nederlands</p><p>wear a mask, stay safe</p><p><a href="https://mastodon.nl/tags/nobot" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>nobot</span></a> should keep the bots at bay</p>',
#    'url': 'https://mastodon.nl/@hvangalen',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/377/379/742/194/038/original/c5d88b942f353c1b.jpg',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/377/379/742/194/038/original/c5d88b942f353c1b.jpg',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/109/377/379/742/194/038/original/40d7005209ad8e8d.jpeg',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/109/377/379/742/194/038/original/40d7005209ad8e8d.jpeg',
#    'followers_count': 589,
#    'following_count': 685,
#    'statuses_count': 6126,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': []},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367214903420596,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 14, 5, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://mastodon.online/users/SRDas/statuses/110367214518810091',
#   'url': 'https://mastodon.online/@SRDas/110367214518810091',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p><a href="https://mastodon.online/tags/SilentSunday" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>SilentSunday</span></a><br><a href="https://mastodon.online/tags/Howrah" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Howrah</span></a> <a href="https://mastodon.online/tags/Garden" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Garden</span></a> <a href="https://mastodon.online/tags/Kolkata" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Kolkata</span></a> <a href="https://mastodon.online/tags/Travel" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Travel</span></a> <a href="https://mastodon.online/tags/Nature" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Nature</span></a> <a href="https://mastodon.online/tags/Photography" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Photography</span></a></p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109354093548746858,
#    'username': 'SRDas',
#    'acct': 'SRDas@mastodon.online',
#    'display_name': 'Das',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 11, 6, 0, 0, tzinfo=tzutc()),
#    'note': '<p>Nucleic Acids <a href="https://mastodon.online/tags/Chemist" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Chemist</span></a>, <a href="https://mastodon.online/tags/Biochemist" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Biochemist</span></a>, <a href="https://mastodon.online/tags/Food" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Food</span></a> &amp; <a href="https://mastodon.online/tags/Drink" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Drink</span></a> Lover - not always in that order. <br>Formerly @KitchenChemProf (Twitter)<br><a href="https://mastodon.online/tags/Homeschooling" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Homeschooling</span></a> Dad of teens. Trying to read more recent SF&amp;F - read a lot in late 80s to 90/00s. <br>Personal, not research lab account.<br>He/him</p><p><a href="https://mastodon.online/tags/FoodScience" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>FoodScience</span></a> <a href="https://mastodon.online/tags/Chemistry" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Chemistry</span></a> <a href="https://mastodon.online/tags/Cooking" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Cooking</span></a> <a href="https://mastodon.online/tags/Gastronomy" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Gastronomy</span></a> <a href="https://mastodon.online/tags/FlavorScience" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>FlavorScience</span></a> <a href="https://mastodon.online/tags/Taste" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Taste</span></a> <a href="https://mastodon.online/tags/BBQ" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>BBQ</span></a> <a href="https://mastodon.online/tags/Curry" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Curry</span></a> <a href="https://mastodon.online/tags/Science" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Science</span></a> <a href="https://mastodon.online/tags/RNA" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>RNA</span></a> <a href="https://mastodon.online/tags/DNA" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>DNA</span></a> <a href="https://mastodon.online/tags/KitchenChemistry" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>KitchenChemistry</span></a> <a href="https://mastodon.online/tags/KitchenScience" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>KitchenScience</span></a> <a href="https://mastodon.online/tags/Academia" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Academia</span></a> <a href="https://mastodon.online/tags/Cocktails" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Cocktails</span></a> <a href="https://mastodon.online/tags/Parenting" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Parenting</span></a> <a href="https://mastodon.online/tags/Kids" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Kids</span></a> <a href="https://mastodon.online/tags/Homeschool" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Homeschool</span></a> <a href="https://mastodon.online/tags/Travel" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Travel</span></a> <a href="https://mastodon.online/tags/Japan" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Japan</span></a> <a ...
#    'url': 'https://mastodon.online/@SRDas',
# ...
#      'verified_at': None},
#     {'name': 'apple music & spotify',
#      'value': '<a href="https://music.apple.com/us/artist/inkjetski/1628719170" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">music.apple.com/us/artist/inkj</span><span class="invisible">etski/1628719170</span></a> / <a href="https://open.spotify.com/artist/5LFoocRYaSWDdYbX1wIj6w?si=8YJ4J4SWT_-UtYkgle6tGg" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">open.spotify.com/artist/5LFooc</span><span class="invisible">RYaSWDdYbX1wIj6w?si=8YJ4J4SWT_-UtYkgle6tGg</span></a>',
#      'verified_at': None},
#     {'name': 'fotoblog',
#      'value': '<a href="https://exchgr.photography" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">exchgr.photography</span><span class="invisible"></span></a>',
#      'verified_at': '2023-05-07T17:21:45.905+00:00'},
#     {'name': 'blog',
#      'value': '<a href="https://www.processthings.com" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="">processthings.com</span><span class="invisible"></span></a>',
#      'verified_at': '2023-05-07T17:21:51.330+00:00'}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 110367213343465325,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 13, 40, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://sysadmin.run/users/hackernews/statuses/110367212893158873',
#   'url': 'https://sysadmin.run/@hackernews/110367212893158873',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p>The Greatest Wealth Transfer in History Is Here, with Familiar (Rich) Winners<br>L: <a href="https://www.nytimes.com/2023/05/14/business/economy/wealth-generations.html" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">nytimes.com/2023/05/14/busines</span><span class="invisible">s/economy/wealth-generations.html</span></a><br>C: <a href="https://news.ycombinator.com/item?id=35937204" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">news.ycombinator.com/item?id=3</span><span class="invisible">5937204</span></a></p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109489310784699355,
#    'username': 'hackernews',
#    'acct': 'hackernews@sysadmin.run',
#    'display_name': 'Hacker News Frontpage',
#    'locked': False,
#    'bot': True,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 12, 10, 0, 0, tzinfo=tzutc()),
#    'note': '<p>I\'m a Mastodon bot that posts new entries from the Hacker News front page. Created by <span class="h-card"><a href="https://sysadmin.run/@jloh" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>jloh</span></a></span>.</p><p>Posts are currently retained for 2 months.</p>',
#    'url': 'https://sysadmin.run/@hackernews',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/489/310/784/699/355/original/384dee29b58980f8.png',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/489/310/784/699/355/original/384dee29b58980f8.png',
#    'header': 'https://mastodon.au/headers/original/missing.png',
#    'header_static': 'https://mastodon.au/headers/original/missing.png',
#    'followers_count': 34,
#    'following_count': 1,
#    'statuses_count': 9982,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'Hacker News',
#      'value': '<a href="https://news.ycombinator.com/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">news.ycombinator.com/</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Created by',
#      'value': '<span class="h-card"><a href="https://sysadmin.run/@jloh" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>jloh</span></a></span>',
#      'verified_at': None},
#     {'name': 'Source',
#      'value': '<a href="https://github.com/jloh/hackernews_bot" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">github.com/jloh/hackernews_bot</span><span class="invisible"></span></a>',
#      'verified_at': None}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': {'url': 'https://www.nytimes.com/2023/05/14/business/economy/wealth-generations.html',
#    'title': 'The Greatest Wealth Transfer in History Is Here, With Familiar (Rich) Winners',
#    'description': 'In an era of surging home and stock values, U.S. family wealth has soared. The trillions of dollars going to heirs will largely reinforce inequality.',
#    'type': 'link',
#    'author_name': 'Talmon Joseph Smith',
#    'author_url': 'https://www.nytimes.com/by/talmon-joseph-smith',
#    'provider_name': 'The New York Times',
#    'provider_url': '',
#    'html': '',
#    'width': 400,
#    'height': 209,
#    'image': 'https://o.mastodon.au/cache/preview_cards/images/003/948/549/original/ca1c0811db404121.png',
#    'embed_url': '',
#    'blurhash': 'UNO__#HXjGyXn~WBo#V@%hofaea}ofoLaekC'},
#   'poll': None},
#  {'id': 110367212839307570,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 13, 37, tzinfo=tzutc()),
#   'in_reply_to_id': 110367076777091446,
#   'in_reply_to_account_id': 109343695630213859,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'pt',
#   'uri': 'https://mastodon.green/users/Bossito/statuses/110367212698132916',
#   'url': 'https://mastodon.green/@Bossito/110367212698132916',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p>PS: But the gays wanted Marco Mengoni, not Loreen: <a href="https://www.romeo.com/en/blog/eurovision-2023-results/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">romeo.com/en/blog/eurovision-2</span><span class="invisible">023-results/</span></a></p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109343695630213859,
#    'username': 'Bossito',
#    'acct': 'Bossito@mastodon.green',
#    'display_name': 'bossito 🇪🇺📺🎶',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 10, 28, 0, 0, tzinfo=tzutc()),
#    'note': '<p>ex-blogger e agora ex-twitter </p><p>de bruxelas com ardor</p><p><a href="https://mastodon.green/tags/StandWithUkraine" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>StandWithUkraine</span></a> 🇺🇦</p><p><a href="https://mastodon.green/tags/Eurovision" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Eurovision</span></a> 🎶 <a href="https://mastodon.green/tags/GreenPolitics" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>GreenPolitics</span></a> 🌱 <a href="https://mastodon.green/tags/incunabulos" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>incunabulos</span></a> <a href="https://mastodon.green/tags/BossitoRecomenda" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>BossitoRecomenda</span></a> 📚 <a href="https://mastodon.green/tags/Bread" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Bread</span></a> <a href="https://mastodon.green/tags/fedi22" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>fedi22</span></a> 🍞 <a href="https://mastodon.green/tags/Brussels" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Brussels</span></a> 🇧🇪 <a href="https://mastodon.green/tags/EUpolitics" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>EUpolitics</span></a> 🇪🇺 <a href="https://mastodon.green/tags/Gay" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Gay</span></a> 🌈 mostly in <a href="https://mastodon.green/tags/Portuguese" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Portuguese</span></a> 🇵🇹 but boosting a lot in 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🇲🇫🇪🇸</p>',
#    'url': 'https://mastodon.green/@Bossito',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/343/695/630/213/859/original/0fce767e081202fe.gif',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/343/695/630/213/859/static/0fce767e081202fe.png',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/109/343/695/630/213/859/original/68060de215b18b64.jpg',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/109/343/695/630/213/859/original/68060de215b18b64.jpg',
#    'followers_count': 2280,
#    'following_count': 2154,
#    'statuses_count': 4496,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [],
#    'fields': []},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': {'url': 'https://www.romeo.com/en/blog/eurovision-2023-results/',
#    'title': 'The Results Are in!',
#    'description': 'Eurovision 2023 Results are in!',
#    'type': 'link',
#    'author_name': '',
#    'author_url': '',
#    'provider_name': 'ROMEO',
#    'provider_url': '',
#    'html': '',
#    'width': 400,
#    'height': 210,
#    'image': 'https://o.mastodon.au/cache/preview_cards/images/003/949/265/original/9da69427f8897591.jpg',
#    'embed_url': '',
#    'blurhash': 'USGtywM|}]%2t5jta#azt8j?Roazj[ayayoL'},
#   'poll': None},
#  {'id': 110367212654914318,
#   'created_at': datetime.datetime(2023, 5, 14, 13, 13, 25, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://infosec.exchange/users/pixelnull/statuses/110367211911711564',
#   'url': 'https://infosec.exchange/@pixelnull/110367211911711564',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'favourited': False,
#   'reblogged': False,
#   'muted': False,
#   'bookmarked': False,
#   'content': '<p>Abigail for PM</p>',
#   'filtered': [],
#   'reblog': None,
#   'account': {'id': 109349570828633649,
#    'username': 'pixelnull',
#    'acct': 'pixelnull@infosec.exchange',
#    'display_name': "pessimism's bae",
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 11, 5, 0, 0, tzinfo=tzutc()),
#    'note': '<p>❌just trying to save what God is trying to kill❌ </p><p>InfoSec Nerd🕵 (SIEM-SOAR-IR-RE)<br>AnCom :ancom:<br><a href="http://uaofsatan.org" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">http://</span><span class="">uaofsatan.org</span><span class="invisible"></span></a> zealot⛧🜏</p><p>🏳️\u200d🌈🏳️\u200d⚧️✊🏿\u200b ♿\u200b:blacker_heart_outline:</p><p>:manjaro: :kde: :python: :lain:</p><p>*opinion=mine*</p>',
#    'url': 'https://infosec.exchange/@pixelnull',
#    'avatar': 'https://o.mastodon.au/cache/accounts/avatars/109/349/570/828/633/649/original/d687108ce3eb7bc7.png',
#    'avatar_static': 'https://o.mastodon.au/cache/accounts/avatars/109/349/570/828/633/649/original/d687108ce3eb7bc7.png',
#    'header': 'https://o.mastodon.au/cache/accounts/headers/109/349/570/828/633/649/original/6d9a1049440c56e1.jpg',
#    'header_static': 'https://o.mastodon.au/cache/accounts/headers/109/349/570/828/633/649/original/6d9a1049440c56e1.jpg',
#    'followers_count': 704,
#    'following_count': 532,
#    'statuses_count': 2165,
#    'last_status_at': datetime.datetime(2023, 5, 14, 0, 0),
#    'emojis': [{'shortcode': 'ancom',
#      'url': 'https://o.mastodon.au/cache/custom_emojis/images/000/104/447/original/6e864bdd2905c51b.png',
#      'static_url': 'https://o.mastodon.au/cache/custom_emojis/images/000/104/447/static/6e864bdd2905c51b.png',
#      'visible_in_picker': True},
#     {'shortcode': 'blacker_heart_outline',
#      'url': 'https://o.mastodon.au/cache/custom_emojis/images/000/098/361/original/3fd1ff838bd28624.png',
#      'static_url': 'https://o.mastodon.au/cache/custom_emojis/images/000/098/361/static/3fd1ff838bd28624.png',
#      'visible_in_picker': True},
#     {'shortcode': 'manjaro',
#      'url': 'https://o.mastodon.au/cache/custom_emojis/images/000/104/448/original/c83748861d912eaa.png',
#      'static_url': 'https://o.mastodon.au/cache/custom_emojis/images/000/104/448/static/c83748861d912eaa.png',
#      'visible_in_picker': True},
#     {'shortcode': 'kde',
#      'url': 'https://o.mastodon.au/cache/custom_emojis/images/000/104/449/original/947ee2249be993e8.png',
#      'static_url': 'https://o.mastodon.au/cache/custom_emojis/images/000/104/449/static/947ee2249be993e8.png',
#      'visible_in_picker': True},
#     {'shortcode': 'python',
#      'url': 'https://o.mastodon.au/cache/custom_emojis/images/000/078/207/original/9bea22d45b5bef65.png',
#      'static_url': 'https://o.mastodon.au/cache/custom_emojis/images/000/078/207/static/9bea22d45b5bef65.png',
#      'visible_in_picker': True},
#     {'shortcode': 'lain',
#      'url': 'https://o.mastodon.au/cache/custom_emojis/images/000/104/450/original/db1ed6a10428e7d1.png',
#      'static_url': 'https://o.mastodon.au/cache/custom_emojis/images/000/104/450/static/db1ed6a10428e7d1.png',
#      'visible_in_picker': True}],
#    'fields': [{'name': 'website',
#      'value': '<a href="http://www.pixelnull.net" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">http://www.</span><span class="">pixelnull.net</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'twitter',
#      'value': '<a href="https://twitter.com/pixelnull" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">twitter.com/pixelnull</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'the things', 'value': 'she/her', 'verified_at': None},
#     {'name': 'location',
#      'value': 'an overcrowded circle of salt',
#      'verified_at': None},
#     {'name': 'pgp',
#      'value': '<a href="http://www.pixelnull.net/pgp.txt" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">http://www.</span><span class="">pixelnull.net/pgp.txt</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'also',
#      'value': '<span class="h-card"><a href="https://infosec.town/@pixelnull" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>pixelnull@infosec.town</span></a></span>',
#      'verified_at': None}]},
#   'media_attachments': [{'id': 110367211987957303,
#     'type': 'video',
#     'url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/211/987/957/303/original/e5edc1dc0dd293c7.mp4',
#     'preview_url': 'https://o.mastodon.au/cache/media_attachments/files/110/367/211/987/957/303/small/e5edc1dc0dd293c7.png',
#     'remote_url': 'https://media.infosec.exchange/infosecmediaeu/media_attachments/files/110/367/211/079/137/866/original/0f3330a034be5afb.mp4',
#     'preview_remote_url': None,
#     'text_url': None,
#     'meta': {'original': {'width': 406,
#       'height': 720,
#       'frame_rate': '30/1',
#       'duration': 118.208,
#       'bitrate': 1940647},
#      'small': {'width': 226,
#       'height': 400,
#       'size': '226x400',
#       'aspect': 0.565}},
#     'description': None,
#     'blurhash': 'UaEoM=VYNITM%NaLNGS69Wo~V?i]i[buslxA'}],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None}]

# %%
import json
from happiness_mining import scoring as hs

class Listener(StreamListener):
    def on_update(self, status):
        data_json = None
        if "content" in status:
            model = hs.happiness_score()
            author_id = status["account"]["id"]
            content = status["content"]
            created_at = status["created_at"]
            score = model.scoring_by_text(content)
            language = status.get("language", "unknown")
            tags = [tag["name"] for tag in status.get("tags", [])]
            data = {
                "author_id": author_id,
                "content": content,
                "created_at": created_at,
                "language": language,
                "hashtags": tags,
                "score": score
            }
            # Only include necessary keys in the JSON output
            keys_to_include = [
                "account_id",
                "content",
                "created_at",
                "language",
                "hashtags",
            ]
            filtered_data = {k: v for k, v in data.items() if k in keys_to_include}
            data_json = json.dumps(filtered_data, indent=2, sort_keys=True, default=str)
        try:
            if data_json is not None:
                self.scores.append(score)
            if len(self.scores) >= 10:
                avg = sum(self.scores) / len(self.scores)
                if avg < 5.5:
                    print("😭 (Below 5.5)", self.scores)
                else:
                    print("😆 (Above 5.5)", self.scores)
                self.scores = self.scores[-9:]
            
        except Exception as e:
            self.scores = []
            self.scores.append(score)
            print(e)

# %% [markdown]
# ### Emoji Streaming

# %%
with open("./api.yaml", encoding="UTF-8") as f:
    cfg = yaml.load(f, Loader=yaml.FullLoader)
    m = Mastodon(
        api_base_url=f"https://mastodon.au",
        access_token=cfg["MASTODON_ACCESS_TOKEN"],
    )
    m.stream_public(Listener())
# Out:
# 'Listener' object has no attribute 'scores'
# 😆 (Above 5.5) [5.574736842105264, 5.671384615384616, 5.343999999999999, 5.805714285714286, 5.653333333333333, 5.783333333333334, 5.813770491803281, 5.674285714285714, 5.672820512820516, 5.72]
# 😆 (Above 5.5) [5.671384615384616, 5.343999999999999, 5.805714285714286, 5.653333333333333, 5.783333333333334, 5.813770491803281, 5.674285714285714, 5.672820512820516, 5.72, 5.693793103448275]
# 😆 (Above 5.5) [5.343999999999999, 5.805714285714286, 5.653333333333333, 5.783333333333334, 5.813770491803281, 5.674285714285714, 5.672820512820516, 5.72, 5.693793103448275, 5.704390243902442]
# 😆 (Above 5.5) [5.805714285714286, 5.653333333333333, 5.783333333333334, 5.813770491803281, 5.674285714285714, 5.672820512820516, 5.72, 5.693793103448275, 5.704390243902442, 5.657142857142857]
# 😆 (Above 5.5) [5.653333333333333, 5.783333333333334, 5.813770491803281, 5.674285714285714, 5.672820512820516, 5.72, 5.693793103448275, 5.704390243902442, 5.657142857142857, 5.192727272727273]
# 😆 (Above 5.5) [5.783333333333334, 5.813770491803281, 5.674285714285714, 5.672820512820516, 5.72, 5.693793103448275, 5.704390243902442, 5.657142857142857, 5.192727272727273, 5.464421052631582]
# 😆 (Above 5.5) [5.813770491803281, 5.674285714285714, 5.672820512820516, 5.72, 5.693793103448275, 5.704390243902442, 5.657142857142857, 5.192727272727273, 5.464421052631582, 5.69272727272727]
# 😆 (Above 5.5) [5.674285714285714, 5.672820512820516, 5.72, 5.693793103448275, 5.704390243902442, 5.657142857142857, 5.192727272727273, 5.464421052631582, 5.69272727272727, 5.714999999999998]
# 😆 (Above 5.5) [5.672820512820516, 5.72, 5.693793103448275, 5.704390243902442, 5.657142857142857, 5.192727272727273, 5.464421052631582, 5.69272727272727, 5.714999999999998, 5.546666666666667]
# 😆 (Above 5.5) [5.72, 5.693793103448275, 5.704390243902442, 5.657142857142857, 5.192727272727273, 5.464421052631582, 5.69272727272727, 5.714999999999998, 5.546666666666667, 5.574736842105264]
# 😆 (Above 5.5) [5.693793103448275, 5.704390243902442, 5.657142857142857, 5.192727272727273, 5.464421052631582, 5.69272727272727, 5.714999999999998, 5.546666666666667, 5.574736842105264, 5.797142857142856]
# 😆 (Above 5.5) [5.704390243902442, 5.657142857142857, 5.192727272727273, 5.464421052631582, 5.69272727272727, 5.714999999999998, 5.546666666666667, 5.574736842105264, 5.797142857142856, 5.75804878048781]
# 😆 (Above 5.5) [5.657142857142857, 5.192727272727273, 5.464421052631582, 5.69272727272727, 5.714999999999998, 5.546666666666667, 5.574736842105264, 5.797142857142856, 5.75804878048781, 5.235555555555556]
# 😆 (Above 5.5) [5.192727272727273, 5.464421052631582, 5.69272727272727, 5.714999999999998, 5.546666666666667, 5.574736842105264, 5.797142857142856, 5.75804878048781, 5.235555555555556, 5.643943661971832]
# 😆 (Above 5.5) [5.464421052631582, 5.69272727272727, 5.714999999999998, 5.546666666666667, 5.574736842105264, 5.797142857142856, 5.75804878048781, 5.235555555555556, 5.643943661971832, 5.546666666666667]
# 😆 (Above 5.5) [5.69272727272727, 5.714999999999998, 5.546666666666667, 5.574736842105264, 5.797142857142856, 5.75804878048781, 5.235555555555556, 5.643943661971832, 5.546666666666667, 5.839999999999998]
# 😆 (Above 5.5) [5.714999999999998, 5.546666666666667, 5.574736842105264, 5.797142857142856, 5.75804878048781, 5.235555555555556, 5.643943661971832, 5.546666666666667, 5.839999999999998, 5.52]
# 😆 (Above 5.5) [5.546666666666667, 5.574736842105264, 5.797142857142856, 5.75804878048781, 5.235555555555556, 5.643943661971832, 5.546666666666667, 5.839999999999998, 5.52, 5.412413793103448]
# 😆 (Above 5.5) [5.574736842105264, 5.797142857142856, 5.75804878048781, 5.235555555555556, 5.643943661971832, 5.546666666666667, 5.839999999999998, 5.52, 5.412413793103448, 5.743448275862068]
# 😆 (Above 5.5) [5.797142857142856, 5.75804878048781, 5.235555555555556, 5.643943661971832, 5.546666666666667, 5.839999999999998, 5.52, 5.412413793103448, 5.743448275862068, 5.650769230769228]
# 😆 (Above 5.5) [5.75804878048781, 5.235555555555556, 5.643943661971832, 5.546666666666667, 5.839999999999998, 5.52, 5.412413793103448, 5.743448275862068, 5.650769230769228, 5.59076923076923]
# 😆 (Above 5.5) [5.235555555555556, 5.643943661971832, 5.546666666666667, 5.839999999999998, 5.52, 5.412413793103448, 5.743448275862068, 5.650769230769228, 5.59076923076923, 5.459999999999999]
# 😆 (Above 5.5) [5.643943661971832, 5.546666666666667, 5.839999999999998, 5.52, 5.412413793103448, 5.743448275862068, 5.650769230769228, 5.59076923076923, 5.459999999999999, 5.739428571428568]
# 😆 (Above 5.5) [5.546666666666667, 5.839999999999998, 5.52, 5.412413793103448, 5.743448275862068, 5.650769230769228, 5.59076923076923, 5.459999999999999, 5.739428571428568, 5.771707317073168]
# 😆 (Above 5.5) [5.839999999999998, 5.52, 5.412413793103448, 5.743448275862068, 5.650769230769228, 5.59076923076923, 5.459999999999999, 5.739428571428568, 5.771707317073168, 5.264]
# 😆 (Above 5.5) [5.52, 5.412413793103448, 5.743448275862068, 5.650769230769228, 5.59076923076923, 5.459999999999999, 5.739428571428568, 5.771707317073168, 5.264, 5.435000000000001]
# 😆 (Above 5.5) [5.412413793103448, 5.743448275862068, 5.650769230769228, 5.59076923076923, 5.459999999999999, 5.739428571428568, 5.771707317073168, 5.264, 5.435000000000001, 5.050000000000001]
# 😆 (Above 5.5) [5.743448275862068, 5.650769230769228, 5.59076923076923, 5.459999999999999, 5.739428571428568, 5.771707317073168, 5.264, 5.435000000000001, 5.050000000000001, 5.351111111111113]
# 😭 (Below 5.5) [5.650769230769228, 5.59076923076923, 5.459999999999999, 5.739428571428568, 5.771707317073168, 5.264, 5.435000000000001, 5.050000000000001, 5.351111111111113, 5.546666666666667]
# 😭 (Below 5.5) [5.59076923076923, 5.459999999999999, 5.739428571428568, 5.771707317073168, 5.264, 5.435000000000001, 5.050000000000001, 5.351111111111113, 5.546666666666667, 5.785846153846155]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       2 cfg = yaml.load(f, Loader=yaml.FullLoader)
#       3 m = Mastodon(
#       4     api_base_url=f"https://mastodon.au",
#       5     access_token=cfg["MASTODON_ACCESS_TOKEN"],
#       6 )
# ----> 7 m.stream_public(Listener())
#
# File ~/Library/Python/3.11/lib/python/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/Documents/GitHub/social-media-analytics-on-cloud/notebook/mastodon_notebook/mastodon/utility.py:49, in api_version.<locals>.api_min_version_decorator.<locals>.wrapper(function, self, *args, **kwargs)
#      47     elif major == self.mastodon_major and minor == self.mastodon_minor and patch > self.mastodon_patch:
#      48         raise MastodonVersionError(f"Version check failed (Need version {version}, patch is {self.mastodon_patch})")
# ---> 49 return function(self, *args, **kwargs)
#
# File ~/Documents/GitHub/social-media-analytics-on-cloud/notebook/mastodon_notebook/mastodon/streaming_endpoints.py:38, in Mastodon.stream_public(self, listener, run_async, timeout, reconnect_async, reconnect_async_wait_sec, local, remote)
#      36         raise MastodonIllegalArgumentError("Cannot pass both local and remote - use either one or the other.")
#      37     base += '/remote'
# ---> 38 return self.__stream(base, listener, run_async=run_async, timeout=timeout, reconnect_async=reconnect_async, reconnect_async_wait_sec=reconnect_async_wait_sec)
#
# File ~/Documents/GitHub/social-media-analytics-on-cloud/notebook/mastodon_notebook/mastodon/internals.py:540, in Mastodon.__stream(self, endpoint, listener, params, run_async, timeout, reconnect_async, reconnect_async_wait_sec)
#     538 connection = connect_func()
#     539 with closing(connection) as r:
# --> 540     listener.handle_stream(r)
#
# File ~/Documents/GitHub/social-media-analytics-on-cloud/notebook/mastodon_notebook/mastodon/streaming.py:109, in StreamListener.handle_stream(self, response)
#     107 line_buffer = bytearray()
#     108 try:
# --> 109     for chunk in response.iter_content(chunk_size=1):
#     110         if chunk:
#     111             for chunk_part in chunk:
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/response.py:932, in HTTPResponse.stream(self, amt, decode_content)
#     916 """
#     917 A generator wrapper for the read() method. A call will block until
#     918 ``amt`` bytes have been read from the connection or until the
#    (...)
#     929     'content-encoding' header.
#     930 """
#     931 if self.chunked and self.supports_chunked_reads():
# --> 932     yield from self.read_chunked(amt, decode_content=decode_content)
#     933 else:
#     934     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/response.py:1072, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1069     return None
#    1071 while True:
# -> 1072     self._update_chunk_length()
#    1073     if self.chunk_left == 0:
#    1074         break
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/response.py:1000, in HTTPResponse._update_chunk_length(self)
#     998 if self.chunk_left is not None:
#     999     return None
# -> 1000 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1001 line = line.split(b";", 1)[0]
#    1002 try:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.2_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.11/3.11.2_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.2_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import mastodon_retrieve
import pandas as pd


# Mastodon
mastodon_retrieve.streaming_mastodon()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jonghopark/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [5.608421052631578]
# 😆 (Above 5.5)
# [5.478620689655171]
# 😭 (Below 5.5)
# [5.451428571428571]
# 😭 (Below 5.5)
# [5.573818181818181]
# 😆 (Above 5.5)
# [5.456]
# 😭 (Below 5.5)
# [5.726769230769229]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.759999999999998]
# 😆 (Above 5.5)
# [5.751111111111111]
# 😆 (Above 5.5)
# [5.2]
# 😭 (Below 5.5)
# [5.812881355932203]
# 😆 (Above 5.5)
# [5.69672727272727]
# 😆 (Above 5.5)
# [5.5921951219512165]
# 😆 (Above 5.5)
# [5.721999999999997]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.777999999999997]
# 😆 (Above 5.5)
# [5.558260869565217]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.751489361702125]
# 😆 (Above 5.5)
# [5.622399999999998]
# 😆 (Above 5.5)
# [5.853913043478257]
# 😆 (Above 5.5)
# [5.622399999999998]
# 😆 (Above 5.5)
# [5.640000000000001]
# 😆 (Above 5.5)
# [5.735384615384616]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.762580645161288]
# 😆 (Above 5.5)
# [5.802352941176472]
# 😆 (Above 5.5)
# [5.787755102040813]
# 😆 (Above 5.5)
# [5.556923076923078]
# 😆 (Above 5.5)
# [5.751666666666665]
# 😆 (Above 5.5)
# [5.794871794871793]
# 😆 (Above 5.5)
# [5.503333333333334]
# 😆 (Above 5.5)
# [5.639999999999997]
# 😆 (Above 5.5)
# [5.599999999999999]
# 😆 (Above 5.5)
# [5.690666666666663]
# 😆 (Above 5.5)
# [5.592727272727271]
# 😆 (Above 5.5)
# [5.634285714285712]
# 😆 (Above 5.5)
# [5.65739130434782]
# 😆 (Above 5.5)
# [5.764571428571426]
# 😆 (Above 5.5)
# [5.86285714285714]
# 😆 (Above 5.5)
# [5.512380952380953]
# 😆 (Above 5.5)
# [5.6141772151898754]
# 😆 (Above 5.5)
# [5.720000000000001]
# 😆 (Above 5.5)
# [5.653333333333333]
# 😆 (Above 5.5)
# [5.526666666666667]
# 😆 (Above 5.5)
# [5.839999999999998]
# 😆 (Above 5.5)
# [5.748571428571429]
# 😆 (Above 5.5)
# [5.552]
# 😆 (Above 5.5)
# [5.617777777777777]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.631219512195118]
# 😆 (Above 5.5)
# [5.459999999999999]
# 😭 (Below 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.751864406779664]
# 😆 (Above 5.5)
# [5.656666666666663]
# 😆 (Above 5.5)
# [5.562033898305085]
# 😆 (Above 5.5)
# [5.7985185185185175]
# 😆 (Above 5.5)
# [5.738947368421053]
# 😆 (Above 5.5)
# [5.6571428571428575]
# 😆 (Above 5.5)
# [5.633333333333334]
# 😆 (Above 5.5)
# [5.629090909090911]
# 😆 (Above 5.5)
# [5.6723809523809505]
# 😆 (Above 5.5)
# [5.44]
# 😭 (Below 5.5)
# [5.706666666666667]
# 😆 (Above 5.5)
# [5.656666666666665]
# 😆 (Above 5.5)
# [5.596363636363633]
# 😆 (Above 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.458285714285714]
# 😭 (Below 5.5)
# [5.78]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.836279069767438]
# 😆 (Above 5.5)
# [5.893913043478256]
# 😆 (Above 5.5)
# [5.8443243243243215]
# 😆 (Above 5.5)
# [5.550638297872338]
# 😆 (Above 5.5)
# [5.74967741935484]
# 😆 (Above 5.5)
# [5.883636363636365]
# 😆 (Above 5.5)
# [5.512533333333335]
# 😆 (Above 5.5)
# [5.728750000000001]
# 😆 (Above 5.5)
# [5.908888888888884]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.509333333333334]
# 😆 (Above 5.5)
# [5.7770212765957405]
# 😆 (Above 5.5)
# [5.853333333333331]
# 😆 (Above 5.5)
# [5.661176470588233]
# 😆 (Above 5.5)
# [5.796791443850255]
# 😆 (Above 5.5)
# [5.816170212765953]
# 😆 (Above 5.5)
# [5.780000000000001]
# 😆 (Above 5.5)
# [5.856551724137928]
# 😆 (Above 5.5)
# [5.608888888888888]
# 😆 (Above 5.5)
# [5.606666666666663]
# 😆 (Above 5.5)
# [5.704999999999998]
# 😆 (Above 5.5)
# [5.770566037735848]
# 😆 (Above 5.5)
# [5.678095238095234]
# 😆 (Above 5.5)
# [5.499393939393943]
# 😭 (Below 5.5)
# [5.816296296296294]
# 😆 (Above 5.5)
# [5.8325]
# 😆 (Above 5.5)
# [5.738181818181817]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.739428571428567]
# 😆 (Above 5.5)
# [5.559999999999996]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.808000000000002]
# 😆 (Above 5.5)
# [5.546666666666667]
# 😆 (Above 5.5)
# [5.142857142857145]
# 😭 (Below 5.5)
# [5.304615384615385]
# 😭 (Below 5.5)
# [5.687058823529411]
# 😆 (Above 5.5)
# [5.625531914893614]
# 😆 (Above 5.5)
# [5.844999999999998]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.656000000000001]
# 😆 (Above 5.5)
# [5.7089361702127635]
# 😆 (Above 5.5)
# [5.5428571428571445]
# 😆 (Above 5.5)
# [5.785974025974028]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.656666666666666]
# 😆 (Above 5.5)
# [5.623880597014925]
# 😆 (Above 5.5)
# [5.553170731707321]
# 😆 (Above 5.5)
# [5.4719999999999995]
# 😭 (Below 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.797419354838711]
# 😆 (Above 5.5)
# [5.751666666666664]
# 😆 (Above 5.5)
# [5.510000000000001]
# 😆 (Above 5.5)
# [5.751724137931032]
# 😆 (Above 5.5)
# [5.500845070422535]
# 😆 (Above 5.5)
# [5.770666666666668]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.705454545454545]
# 😆 (Above 5.5)
# [5.812244897959181]
# 😆 (Above 5.5)
# [5.392]
# 😭 (Below 5.5)
# [5.693559322033895]
# 😆 (Above 5.5)
# [5.654468085106379]
# 😆 (Above 5.5)
# [5.6800000000000015]
# 😆 (Above 5.5)
# [5.533333333333334]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.9013953488372035]
# 😆 (Above 5.5)
# [5.547586206896549]
# 😆 (Above 5.5)
# [5.512727272727273]
# 😆 (Above 5.5)
# [5.6557575757575735]
# 😆 (Above 5.5)
# [5.546666666666667]
# 😆 (Above 5.5)
# [5.809361702127656]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.685633802816901]
# 😆 (Above 5.5)
# [5.771428571428572]
# 😆 (Above 5.5)
# [5.373333333333334]
# 😭 (Below 5.5)
# [5.64]
# 😆 (Above 5.5)
# [5.439999999999998]
# 😭 (Below 5.5)
# [5.568372093023254]
# 😆 (Above 5.5)
# [5.833846153846153]
# 😆 (Above 5.5)
# [5.919999999999999]
# 😆 (Above 5.5)
# [5.698604651162788]
# 😆 (Above 5.5)
# [5.831111111111111]
# 😆 (Above 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.5649999999999995]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.6612765957446785]
# 😆 (Above 5.5)
# [5.529777777777782]
# 😆 (Above 5.5)
# [5.690322580645159]
# 😆 (Above 5.5)
# [5.840000000000001]
# 😆 (Above 5.5)
# [5.716521739130432]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.728888888888886]
# 😆 (Above 5.5)
# [5.7973333333333334]
# 😆 (Above 5.5)
# [5.777142857142856]
# 😆 (Above 5.5)
# [5.52]
# 😆 (Above 5.5)
# [5.637999999999996]
# 😆 (Above 5.5)
# [5.367999999999999]
# 😭 (Below 5.5)
# [5.546666666666667]
# 😆 (Above 5.5)
# [5.650000000000001]
# 😆 (Above 5.5)
# [5.637999999999996]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.394285714285714]
# 😭 (Below 5.5)
# [0]
# 😭 (Below 5.5)
# [5.8799999999999955]
# 😆 (Above 5.5)
# [5.671111111111112]
# 😆 (Above 5.5)
# [5.661538461538461]
# 😆 (Above 5.5)
# [5.715555555555555]
# 😆 (Above 5.5)
# [5.786666666666668]
# 😆 (Above 5.5)
# [5.705454545454547]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.652048192771089]
# 😆 (Above 5.5)
# [5.539310344827586]
# 😆 (Above 5.5)
# [5.212307692307691]
# 😭 (Below 5.5)
# [0]
# 😭 (Below 5.5)
# [4.48]
# 😭 (Below 5.5)
# [5.726315789473685]
# 😆 (Above 5.5)
# [5.797073170731704]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.611707317073168]
# 😆 (Above 5.5)
# [5.4799999999999995]
# 😭 (Below 5.5)
# [5.7233898305084745]
# 😆 (Above 5.5)
# [5.485000000000001]
# 😭 (Below 5.5)
# [5.645217391304348]
# 😆 (Above 5.5)
# [5.554285714285714]
# 😆 (Above 5.5)
# [5.655652173913044]
# 😆 (Above 5.5)
# [5.883636363636364]
# 😆 (Above 5.5)
# [5.6759999999999975]
# 😆 (Above 5.5)
# [5.70153846153846]
# 😆 (Above 5.5)
# [5.59]
# 😆 (Above 5.5)
# [5.8158490566037715]
# 😆 (Above 5.5)
# [5.44]
# 😭 (Below 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.336]
# 😭 (Below 5.5)
# [5.887567567567563]
# 😆 (Above 5.5)
# [5.76406779661017]
# 😆 (Above 5.5)
# [5.524897959183671]
# 😆 (Above 5.5)
# [5.542857142857143]
# 😆 (Above 5.5)
# [5.632941176470588]
# 😆 (Above 5.5)
# [5.590588235294116]
# 😆 (Above 5.5)
# [5.583448275862067]
# 😆 (Above 5.5)
# [5.826086956521734]
# 😆 (Above 5.5)
# [5.796363636363634]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.881290322580642]
# 😆 (Above 5.5)
# [5.919999999999999]
# 😆 (Above 5.5)
# [5.456]
# 😭 (Below 5.5)
# [5.776623376623378]
# 😆 (Above 5.5)
# [5.574634146341459]
# 😆 (Above 5.5)
# [5.694285714285714]
# 😆 (Above 5.5)
# [5.743999999999995]
# 😆 (Above 5.5)
# [5.742499999999998]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.791999999999999]
# 😆 (Above 5.5)
# [5.547826086956522]
# 😆 (Above 5.5)
# [5.607466666666669]
# 😆 (Above 5.5)
# [5.70074074074074]
# 😆 (Above 5.5)
# [5.832499999999999]
# 😆 (Above 5.5)
# [5.800816326530609]
# 😆 (Above 5.5)
# [5.847272727272732]
# 😆 (Above 5.5)
# [5.627317073170728]
# 😆 (Above 5.5)
# [5.722105263157891]
# 😆 (Above 5.5)
# [5.843076923076922]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.629866666666671]
# 😆 (Above 5.5)
# [5.805714285714286]
# 😆 (Above 5.5)
# [5.7333333333333325]
# 😆 (Above 5.5)
# [5.568888888888889]
# 😆 (Above 5.5)
# [5.736774193548387]
# 😆 (Above 5.5)
# [5.7765517241379305]
# 😆 (Above 5.5)
# [5.546666666666667]
# 😆 (Above 5.5)
# [4.96]
# 😭 (Below 5.5)
# [5.563999999999999]
# 😆 (Above 5.5)
# [5.526153846153846]
# 😆 (Above 5.5)
# [5.626666666666667]
# 😆 (Above 5.5)
# [5.680000000000001]
# 😆 (Above 5.5)
# [5.432592592592591]
# 😭 (Below 5.5)
# [5.665777777777775]
# 😆 (Above 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.514285714285713]
# 😆 (Above 5.5)
# [5.9199999999999955]
# 😆 (Above 5.5)
# [5.597499999999999]
# 😆 (Above 5.5)
# [5.4048]
# 😭 (Below 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.682222222222225]
# 😆 (Above 5.5)
# [5.803428571428568]
# 😆 (Above 5.5)
# [5.560000000000003]
# 😆 (Above 5.5)
# [5.611707317073168]
# 😆 (Above 5.5)
# [5.368205128205126]
# 😭 (Below 5.5)
# [5.634285714285711]
# 😆 (Above 5.5)
# [5.721081081081077]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.807179487179484]
# 😆 (Above 5.5)
# [5.676923076923075]
# 😆 (Above 5.5)
# [5.88923076923077]
# 😆 (Above 5.5)
# [5.66260869565217]
# 😆 (Above 5.5)
# [5.7360000000000015]
# 😆 (Above 5.5)
# [5.392]
# 😭 (Below 5.5)
# [5.778823529411763]
# 😆 (Above 5.5)
# [5.8771428571428554]
# 😆 (Above 5.5)
# [5.642352941176473]
# 😆 (Above 5.5)
# [5.607441860465113]
# 😆 (Above 5.5)
# [5.717333333333333]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.548571428571427]
# 😆 (Above 5.5)
# [5.733333333333331]
# 😆 (Above 5.5)
# [5.618461538461537]
# 😆 (Above 5.5)
# [5.643870967741934]
# 😆 (Above 5.5)
# [5.355294117647059]
# 😭 (Below 5.5)
# [5.652499999999998]
# 😆 (Above 5.5)
# [5.775999999999996]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.624347826086957]
# 😆 (Above 5.5)
# [5.495384615384617]
# 😭 (Below 5.5)
# [5.727999999999998]
# 😆 (Above 5.5)
# [5.717142857142855]
# 😆 (Above 5.5)
# [5.728120300751871]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.735094339622638]
# 😆 (Above 5.5)
# [5.418181818181818]
# 😭 (Below 5.5)
# [5.722499999999997]
# 😆 (Above 5.5)
# [5.465999999999999]
# 😭 (Below 5.5)
# [5.606101694915253]
# 😆 (Above 5.5)
# [5.732571428571425]
# 😆 (Above 5.5)
# [5.716363636363634]
# 😆 (Above 5.5)
# [5.613333333333333]
# 😆 (Above 5.5)
# [5.240000000000001]
# 😭 (Below 5.5)
# [5.26]
# 😭 (Below 5.5)
# [5.51]
# 😆 (Above 5.5)
# [5.715555555555556]
# 😆 (Above 5.5)
# [5.597419354838709]
# 😆 (Above 5.5)
# [5.89142857142857]
# 😆 (Above 5.5)
# [5.805714285714286]
# 😆 (Above 5.5)
# [5.771764705882355]
# 😆 (Above 5.5)
# [5.880000000000001]
# 😆 (Above 5.5)
# [5.466666666666664]
# 😭 (Below 5.5)
# [5.840000000000001]
# 😆 (Above 5.5)
# [5.61888198757763]
# 😆 (Above 5.5)
# [5.900952380952382]
# 😆 (Above 5.5)
# [5.782641509433961]
# 😆 (Above 5.5)
# [5.684324324324321]
# 😆 (Above 5.5)
# [5.673333333333334]
# 😆 (Above 5.5)
# [5.44]
# 😭 (Below 5.5)
# [5.672941176470585]
# 😆 (Above 5.5)
# [5.402105263157896]
# 😭 (Below 5.5)
# [5.783225806451611]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.887999999999996]
# 😆 (Above 5.5)
# [5.853333333333333]
# 😆 (Above 5.5)
# [5.638095238095239]
# 😆 (Above 5.5)
# [5.790588235294118]
# 😆 (Above 5.5)
# [5.883636363636365]
# 😆 (Above 5.5)
# [5.746382978723401]
# 😆 (Above 5.5)
# [5.394285714285713]
# 😭 (Below 5.5)
# [5.7755555555555524]
# 😆 (Above 5.5)
# [5.63]
# 😆 (Above 5.5)
# [5.759999999999997]
# 😆 (Above 5.5)
# [5.62]
# 😆 (Above 5.5)
# [5.585454545454543]
# 😆 (Above 5.5)
# [5.485714285714285]
# 😭 (Below 5.5)
# [5.870344827586206]
# 😆 (Above 5.5)
# [5.705365853658531]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.58967741935484]
# 😆 (Above 5.5)
# [5.781694915254238]
# 😆 (Above 5.5)
# [5.594666666666668]
# 😆 (Above 5.5)
# [5.6868571428571455]
# 😆 (Above 5.5)
# [5.585454545454547]
# 😆 (Above 5.5)
# [5.8299999999999965]
# 😆 (Above 5.5)
# [5.714285714285715]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.521454545454543]
# 😆 (Above 5.5)
# [5.867368421052627]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.851999999999992]
# 😆 (Above 5.5)
# [5.671111111111112]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.710967741935481]
# 😆 (Above 5.5)
# [5.801379310344826]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.498181818181817]
# 😭 (Below 5.5)
# [5.526153846153847]
# 😆 (Above 5.5)
# [5.853333333333333]
# 😆 (Above 5.5)
# [5.828196721311475]
# 😆 (Above 5.5)
# [5.76]
# 😆 (Above 5.5)
# [5.763265306122447]
# 😆 (Above 5.5)
# [5.513333333333333]
# 😆 (Above 5.5)
# [5.868387096774191]
# 😆 (Above 5.5)
# [5.765333333333332]
# 😆 (Above 5.5)
# [5.594074074074073]
# 😆 (Above 5.5)
# [5.688888888888883]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.877014925373136]
# 😆 (Above 5.5)
# [5.880000000000001]
# 😆 (Above 5.5)
# [5.716000000000001]
# 😆 (Above 5.5)
# [5.654399999999998]
# 😆 (Above 5.5)
# [5.880000000000001]
# 😆 (Above 5.5)
# [5.280000000000001]
# 😭 (Below 5.5)
# [5.648888888888887]
# 😆 (Above 5.5)
# [5.724347826086956]
# 😆 (Above 5.5)
# [5.6594285714285695]
# 😆 (Above 5.5)
# [5.776000000000001]
# 😆 (Above 5.5)
# [5.679999999999997]
# 😆 (Above 5.5)
# [5.626046511627903]
# 😆 (Above 5.5)
# [5.660689655172413]
# 😆 (Above 5.5)
# [5.715999999999997]
# 😆 (Above 5.5)
# [5.619999999999998]
# 😆 (Above 5.5)
# [5.7755555555555524]
# 😆 (Above 5.5)
# [5.5911111111111085]
# 😆 (Above 5.5)
# [5.800000000000001]
# 😆 (Above 5.5)
# [5.5822222222222235]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.585454545454547]
# 😆 (Above 5.5)
# [5.661538461538461]
# 😆 (Above 5.5)
# [5.571147540983606]
# 😆 (Above 5.5)
# [5.709473684210522]
# 😆 (Above 5.5)
# [5.88923076923077]
# 😆 (Above 5.5)
# [5.408]
# 😭 (Below 5.5)
# [5.728888888888886]
# 😆 (Above 5.5)
# [5.768275862068966]
# 😆 (Above 5.5)
# [5.838181818181821]
# 😆 (Above 5.5)
# [5.811666666666664]
# 😆 (Above 5.5)
# [5.5404651162790675]
# 😆 (Above 5.5)
# [5.647500000000001]
# 😆 (Above 5.5)
# [5.583589743589742]
# 😆 (Above 5.5)
# [5.5009523809523815]
# 😆 (Above 5.5)
# [5.617777777777776]
# 😆 (Above 5.5)
# [5.584999999999997]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.686153846153847]
# 😆 (Above 5.5)
# [5.779649122807015]
# 😆 (Above 5.5)
# [5.720000000000001]
# 😆 (Above 5.5)
# [5.2]
# 😭 (Below 5.5)
# [5.729032258064516]
# 😆 (Above 5.5)
# [5.739259259259257]
# 😆 (Above 5.5)
# [5.88618556701031]
# 😆 (Above 5.5)
# [5.667826086956518]
# 😆 (Above 5.5)
# [5.498666666666666]
# 😭 (Below 5.5)
# [5.849411764705878]
# 😆 (Above 5.5)
# [5.697777777777775]
# 😆 (Above 5.5)
# [5.722666666666664]
# 😆 (Above 5.5)
# [5.498947368421054]
# 😭 (Below 5.5)
# [5.6985714285714275]
# 😆 (Above 5.5)
# [5.715555555555555]
# 😆 (Above 5.5)
# [5.682807017543859]
# 😆 (Above 5.5)
# [5.713488372093021]
# 😆 (Above 5.5)
# [5.751111111111109]
# 😆 (Above 5.5)
# [5.784444444444443]
# 😆 (Above 5.5)
# [5.68]
# 😆 (Above 5.5)
# [5.679999999999998]
# 😆 (Above 5.5)
# [5.696744186046508]
# 😆 (Above 5.5)
# [5.813333333333334]
# 😆 (Above 5.5)
# [5.636923076923076]
# 😆 (Above 5.5)
# [5.68]
# 😆 (Above 5.5)
# [5.578181818181817]
# 😆 (Above 5.5)
# [5.8575]
# 😆 (Above 5.5)
# [5.501276595744676]
# 😆 (Above 5.5)
# [5.7691803278688525]
# 😆 (Above 5.5)
# [5.849411764705883]
# 😆 (Above 5.5)
# [5.588837209302324]
# 😆 (Above 5.5)
# [5.766153846153845]
# 😆 (Above 5.5)
# [5.46]
# 😭 (Below 5.5)
# [5.5120000000000005]
# 😆 (Above 5.5)
# [5.790684931506851]
# 😆 (Above 5.5)
# [5.707826086956522]
# 😆 (Above 5.5)
# [5.805000000000001]
# 😆 (Above 5.5)
# [5.839999999999996]
# 😆 (Above 5.5)
# [5.680000000000001]
# 😆 (Above 5.5)
# [5.86074074074074]
# 😆 (Above 5.5)
# [5.794999999999998]
# 😆 (Above 5.5)
# [5.866666666666668]
# 😆 (Above 5.5)
# [5.645283018867922]
# 😆 (Above 5.5)
# [5.575384615384615]
# 😆 (Above 5.5)
# [5.44]
# 😭 (Below 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.5634285714285685]
# 😆 (Above 5.5)
# [5.691428571428568]
# 😆 (Above 5.5)
# [5.624615384615381]
# 😆 (Above 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.599999999999997]
# 😆 (Above 5.5)
# [5.627826086956523]
# 😆 (Above 5.5)
# [5.544761904761901]
# 😆 (Above 5.5)
# [5.719999999999996]
# 😆 (Above 5.5)
# [5.525714285714287]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.818181818181819]
# 😆 (Above 5.5)
# [5.57142857142857]
# 😆 (Above 5.5)
# [5.716705882352944]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.665777777777773]
# 😆 (Above 5.5)
# [5.65189189189189]
# 😆 (Above 5.5)
# [5.670399999999996]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.52]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.742608695652175]
# 😆 (Above 5.5)
# [5.625882352941174]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.4719999999999995]
# 😭 (Below 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.7773913043478275]
# 😆 (Above 5.5)
# [5.711515151515153]
# 😆 (Above 5.5)
# [5.870000000000001]
# 😆 (Above 5.5)
# [5.755294117647057]
# 😆 (Above 5.5)
# [5.656470588235291]
# 😆 (Above 5.5)
# [5.6246153846153835]
# 😆 (Above 5.5)
# [5.671304347826083]
# 😆 (Above 5.5)
# [5.6325925925925935]
# 😆 (Above 5.5)
# [5.801818181818178]
# 😆 (Above 5.5)
# [5.4852173913043485]
# 😭 (Below 5.5)
# [5.8875247524752465]
# 😆 (Above 5.5)
# [5.775384615384612]
# 😆 (Above 5.5)
# [5.680000000000002]
# 😆 (Above 5.5)
# [5.51627906976744]
# 😆 (Above 5.5)
# [5.6369230769230745]
# 😆 (Above 5.5)
# [5.70360655737705]
# 😆 (Above 5.5)
# [5.726376811594203]
# 😆 (Above 5.5)
# [5.657499999999997]
# 😆 (Above 5.5)
# [5.5717647058823525]
# 😆 (Above 5.5)
# [5.796190476190474]
# 😆 (Above 5.5)
# [5.491999999999999]
# 😭 (Below 5.5)
# [5.853333333333334]
# 😆 (Above 5.5)
# [5.618571428571426]
# 😆 (Above 5.5)
# [5.426666666666666]
# 😭 (Below 5.5)
# [5.448421052631581]
# 😭 (Below 5.5)
# [5.65142857142857]
# 😆 (Above 5.5)
# [5.751489361702124]
# 😆 (Above 5.5)
# [5.603076923076921]
# 😆 (Above 5.5)
# [5.6968421052631575]
# 😆 (Above 5.5)
# [5.737999999999997]
# 😆 (Above 5.5)
# [5.700408163265305]
# 😆 (Above 5.5)
# [5.760000000000001]
# 😆 (Above 5.5)
# [5.664999999999997]
# 😆 (Above 5.5)
# [5.066666666666666]
# 😭 (Below 5.5)
# [5.495384615384617]
# 😭 (Below 5.5)
# [5.264]
# 😭 (Below 5.5)
# [5.871999999999999]
# 😆 (Above 5.5)
# [5.625531914893616]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.862857142857144]
# 😆 (Above 5.5)
# [5.0]
# 😭 (Below 5.5)
# [5.46]
# 😭 (Below 5.5)
# [5.826666666666665]
# 😆 (Above 5.5)
# [5.847999999999998]
# 😆 (Above 5.5)
# [5.848000000000001]
# 😆 (Above 5.5)
# [5.188571428571429]
# 😭 (Below 5.5)
# [5.531914893617019]
# 😆 (Above 5.5)
# [5.4719999999999995]
# 😭 (Below 5.5)
# [5.620512820512818]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.460363636363636]
# 😭 (Below 5.5)
# [0]
# 😭 (Below 5.5)
# [5.824761904761905]
# 😆 (Above 5.5)
# [5.675789473684211]
# 😆 (Above 5.5)
# [5.621818181818183]
# 😆 (Above 5.5)
# [5.536470588235293]
# 😆 (Above 5.5)
# [5.662222222222222]
# 😆 (Above 5.5)
# [5.7700000000000005]
# 😆 (Above 5.5)
# [5.750537634408604]
# 😆 (Above 5.5)
# [5.837037037037034]
# 😆 (Above 5.5)
# [5.574736842105259]
# 😆 (Above 5.5)
# [5.534117647058826]
# 😆 (Above 5.5)
# [5.380000000000001]
# 😭 (Below 5.5)
# [5.716000000000002]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.632000000000001]
# 😆 (Above 5.5)
# [5.703529411764706]
# 😆 (Above 5.5)
# [5.653333333333331]
# 😆 (Above 5.5)
# [5.781538461538457]
# 😆 (Above 5.5)
# [5.794999999999998]
# 😆 (Above 5.5)
# [5.875555555555554]
# 😆 (Above 5.5)
# [5.474545454545453]
# 😭 (Below 5.5)
# [5.685818181818179]
# 😆 (Above 5.5)
# [5.59]
# 😆 (Above 5.5)
# [5.788000000000001]
# 😆 (Above 5.5)
# [5.629473684210527]
# 😆 (Above 5.5)
# [5.89777777777778]
# 😆 (Above 5.5)
# [5.800000000000001]
# 😆 (Above 5.5)
# [5.852307692307687]
# 😆 (Above 5.5)
# [5.811764705882349]
# 😆 (Above 5.5)
# [5.73485714285714]
# 😆 (Above 5.5)
# [5.764848484848482]
# 😆 (Above 5.5)
# [5.772903225806452]
# 😆 (Above 5.5)
# [5.570461538461539]
# 😆 (Above 5.5)
# [5.640975609756095]
# 😆 (Above 5.5)
# [5.652413793103447]
# 😆 (Above 5.5)
# [5.279999999999999]
# 😭 (Below 5.5)
# [5.546666666666667]
# 😆 (Above 5.5)
# [5.757669902912615]
# 😆 (Above 5.5)
# [5.7773913043478275]
# 😆 (Above 5.5)
# [5.628108108108106]
# 😆 (Above 5.5)
# [5.791219512195118]
# 😆 (Above 5.5)
# [5.443333333333332]
# 😭 (Below 5.5)
# [5.24]
# 😭 (Below 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.645373134328358]
# 😆 (Above 5.5)
# [4.48]
# 😭 (Below 5.5)
# [4.48]
# 😭 (Below 5.5)
# [0]
# 😭 (Below 5.5)
# [5.632000000000001]
# 😆 (Above 5.5)
# [5.287272727272727]
# 😭 (Below 5.5)
# [5.456000000000001]
# 😭 (Below 5.5)
# [5.582857142857144]
# 😆 (Above 5.5)
# [5.306666666666667]
# 😭 (Below 5.5)
# [5.712432432432431]
# 😆 (Above 5.5)
# [5.817777777777779]
# 😆 (Above 5.5)
# [5.2]
# 😭 (Below 5.5)
# [5.831111111111112]
# 😆 (Above 5.5)
# [5.306666666666667]
# 😭 (Below 5.5)
# [5.262222222222223]
# 😭 (Below 5.5)
# [4.48]
# 😭 (Below 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.0]
# 😭 (Below 5.5)
# [5.69]
# 😆 (Above 5.5)
# [5.613333333333334]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.7825]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.714022988505748]
# 😆 (Above 5.5)
# [5.868387096774193]
# 😆 (Above 5.5)
# [5.475862068965517]
# 😭 (Below 5.5)
# [5.392727272727272]
# 😭 (Below 5.5)
# [5.2]
# 😭 (Below 5.5)
# [5.627317073170728]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.685714285714286]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.826666666666665]
# 😆 (Above 5.5)
# [5.639999999999998]
# 😆 (Above 5.5)
# [5.621818181818183]
# 😆 (Above 5.5)
# [5.680000000000001]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.5120000000000005]
# 😆 (Above 5.5)
# [5.595636363636363]
# 😆 (Above 5.5)
# [5.621538461538462]
# 😆 (Above 5.5)
# [5.561212121212121]
# 😆 (Above 5.5)
# [5.52]
# 😆 (Above 5.5)
# [5.401941747572816]
# 😭 (Below 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.754545454545452]
# 😆 (Above 5.5)
# [5.41]
# 😭 (Below 5.5)
# [5.786666666666668]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.684383561643839]
# 😆 (Above 5.5)
# [5.427027027027023]
# 😭 (Below 5.5)
# [5.582068965517239]
# 😆 (Above 5.5)
# [5.685581395348833]
# 😆 (Above 5.5)
# [5.656888888888884]
# 😆 (Above 5.5)
# [5.4719999999999995]
# 😭 (Below 5.5)
# [5.729655172413791]
# 😆 (Above 5.5)
# [5.853333333333331]
# 😆 (Above 5.5)
# [5.826666666666665]
# 😆 (Above 5.5)
# [5.749333333333331]
# 😆 (Above 5.5)
# [5.658181818181818]
# 😆 (Above 5.5)
# [5.715789473684207]
# 😆 (Above 5.5)
# [5.385714285714285]
# 😭 (Below 5.5)
# [5.493333333333333]
# 😭 (Below 5.5)
# [5.649473684210527]
# 😆 (Above 5.5)
# [5.715000000000001]
# 😆 (Above 5.5)
# [5.699999999999999]
# 😆 (Above 5.5)
# [5.653333333333332]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.560000000000001]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.76510638297872]
# 😆 (Above 5.5)
# [5.789473684210527]
# 😆 (Above 5.5)
# [5.3878260869565215]
# 😭 (Below 5.5)
# [5.815384615384612]
# 😆 (Above 5.5)
# [5.60842105263158]
# 😆 (Above 5.5)
# [5.545747126436784]
# 😆 (Above 5.5)
# [5.621052631578947]
# 😆 (Above 5.5)
# [5.694545454545451]
# 😆 (Above 5.5)
# [5.662950819672132]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.0]
# 😭 (Below 5.5)
# [5.823157894736844]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.828965517241378]
# 😆 (Above 5.5)
# [5.694285714285713]
# 😆 (Above 5.5)
# [5.685581395348833]
# 😆 (Above 5.5)
# [5.656888888888885]
# 😆 (Above 5.5)
# [5.791999999999997]
# 😆 (Above 5.5)
# [5.6096]
# 😆 (Above 5.5)
# [5.649230769230767]
# 😆 (Above 5.5)
# [5.707118644067797]
# 😆 (Above 5.5)
# [5.672727272727271]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.689696969696967]
# 😆 (Above 5.5)
# [5.854693877551018]
# 😆 (Above 5.5)
# [5.851034482758618]
# 😆 (Above 5.5)
# [5.796363636363633]
# 😆 (Above 5.5)
# [5.834285714285714]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.40888888888889]
# 😭 (Below 5.5)
# [5.653333333333332]
# 😆 (Above 5.5)
# [5.546666666666667]
# 😆 (Above 5.5)
# [5.643921568627448]
# 😆 (Above 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.578378378378377]
# 😆 (Above 5.5)
# [5.733333333333333]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.8533333333333335]
# 😆 (Above 5.5)
# [5.657142857142857]
# 😆 (Above 5.5)
# [5.567272727272728]
# 😆 (Above 5.5)
# [5.6590654205607445]
# 😆 (Above 5.5)
# [5.632]
# 😆 (Above 5.5)
# [5.694814814814813]
# 😆 (Above 5.5)
# [5.695319148936167]
# 😆 (Above 5.5)
# [5.7321739130434795]
# 😆 (Above 5.5)
# [5.76]
# 😆 (Above 5.5)
# [5.660259740259742]
# 😆 (Above 5.5)
# [5.919999999999999]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.368]
# 😭 (Below 5.5)
# [5.710769230769227]
# 😆 (Above 5.5)
# [5.457777777777777]
# 😭 (Below 5.5)
# [0]
# 😭 (Below 5.5)
# [5.744615384615383]
# 😆 (Above 5.5)
# [5.323636363636365]
# 😭 (Below 5.5)
# [5.715555555555556]
# 😆 (Above 5.5)
# [5.77]
# 😆 (Above 5.5)
# [5.525714285714282]
# 😆 (Above 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.5776]
# 😆 (Above 5.5)
# [5.7655172413793085]
# 😆 (Above 5.5)
# [5.669565217391306]
# 😆 (Above 5.5)
# [5.376000000000001]
# 😭 (Below 5.5)
# [5.510588235294119]
# 😆 (Above 5.5)
# [5.602857142857147]
# 😆 (Above 5.5)
# [5.445000000000001]
# 😭 (Below 5.5)
# [5.7018181818181795]
# 😆 (Above 5.5)
# [5.306666666666667]
# 😭 (Below 5.5)
# [5.487999999999998]
# 😭 (Below 5.5)
# [5.781573033707868]
# 😆 (Above 5.5)
# [5.628571428571426]
# 😆 (Above 5.5)
# [5.621818181818183]
# 😆 (Above 5.5)
# [5.754285714285713]
# 😆 (Above 5.5)
# [5.804999999999997]
# 😆 (Above 5.5)
# [5.628888888888892]
# 😆 (Above 5.5)
# [5.869999999999997]
# 😆 (Above 5.5)
# [5.566315789473682]
# 😆 (Above 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.503448275862068]
# 😆 (Above 5.5)
# [5.806666666666661]
# 😆 (Above 5.5)
# [5.720975609756094]
# 😆 (Above 5.5)
# [5.794285714285715]
# 😆 (Above 5.5)
# [5.893333333333334]
# 😆 (Above 5.5)
# [5.720000000000001]
# 😆 (Above 5.5)
# [5.5771428571428565]
# 😆 (Above 5.5)
# [5.5440000000000005]
# 😆 (Above 5.5)
# [5.631111111111107]
# 😆 (Above 5.5)
# [5.681860465116274]
# 😆 (Above 5.5)
# [5.676923076923075]
# 😆 (Above 5.5)
# [4.48]
# 😭 (Below 5.5)
# [5.8342857142857145]
# 😆 (Above 5.5)
# [5.831111111111111]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.598367346938774]
# 😆 (Above 5.5)
# [5.840000000000001]
# 😆 (Above 5.5)
# [5.795151515151517]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.602962962962962]
# 😆 (Above 5.5)
# [5.6430769230769195]
# 😆 (Above 5.5)
# [5.6499145299145255]
# 😆 (Above 5.5)
# [5.870000000000001]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.790399999999997]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.770434782608697]
# 😆 (Above 5.5)
# [5.415384615384617]
# 😭 (Below 5.5)
# [5.77176470588235]
# 😆 (Above 5.5)
# [5.797073170731704]
# 😆 (Above 5.5)
# [5.593207547169808]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.819393939393939]
# 😆 (Above 5.5)
# [5.692972972972972]
# 😆 (Above 5.5)
# [5.800851063829785]
# 😆 (Above 5.5)
# [5.68421052631579]
# 😆 (Above 5.5)
# [5.527272727272728]
# 😆 (Above 5.5)
# [5.501538461538463]
# 😆 (Above 5.5)
# [4.96]
# 😭 (Below 5.5)
# [5.604571428571426]
# 😆 (Above 5.5)
# [5.71016393442623]
# 😆 (Above 5.5)
# [5.7592]
# 😆 (Above 5.5)
# [5.665454545454542]
# 😆 (Above 5.5)
# [5.883636363636365]
# 😆 (Above 5.5)
# [5.868888888888884]
# 😆 (Above 5.5)
# [5.755999999999997]
# 😆 (Above 5.5)
# [5.77]
# 😆 (Above 5.5)
# [5.450666666666663]
# 😭 (Below 5.5)
# [5.851428571428568]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.632941176470588]
# 😆 (Above 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.733333333333328]
# 😆 (Above 5.5)
# [5.5200000000000005]
# 😆 (Above 5.5)
# [5.726315789473681]
# 😆 (Above 5.5)
# [5.807457627118644]
# 😆 (Above 5.5)
# [5.633333333333333]
# 😆 (Above 5.5)
# [5.89142857142857]
# 😆 (Above 5.5)
# [5.68421052631579]
# 😆 (Above 5.5)
# [5.719999999999994]
# 😆 (Above 5.5)
# [5.552]
# 😆 (Above 5.5)
# [5.589189189189186]
# 😆 (Above 5.5)
# [5.46]
# 😭 (Below 5.5)
# [5.52]
# 😆 (Above 5.5)
# [5.511111111111111]
# 😆 (Above 5.5)
# [5.742222222222223]
# 😆 (Above 5.5)
# [5.714285714285715]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.707397260273976]
# 😆 (Above 5.5)
# [5.665116279069765]
# 😆 (Above 5.5)
# [5.676923076923075]
# 😆 (Above 5.5)
# [5.6066666666666665]
# 😆 (Above 5.5)
# [5.693793103448274]
# 😆 (Above 5.5)
# [5.69098039215686]
# 😆 (Above 5.5)
# [5.763478260869567]
# 😆 (Above 5.5)
# [5.66153846153846]
# 😆 (Above 5.5)
# [5.793846153846153]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.622857142857144]
# 😆 (Above 5.5)
# [5.510000000000001]
# 😆 (Above 5.5)
# [5.765925925925924]
# 😆 (Above 5.5)
# [5.498666666666667]
# 😭 (Below 5.5)
# [5.6130232558139515]
# 😆 (Above 5.5)
# [5.818461538461538]
# 😆 (Above 5.5)
# [5.800930232558134]
# 😆 (Above 5.5)
# [5.280000000000001]
# 😭 (Below 5.5)
# [5.749841269841271]
# 😆 (Above 5.5)
# [5.612631578947367]
# 😆 (Above 5.5)
# [5.546666666666665]
# 😆 (Above 5.5)
# [5.730909090909094]
# 😆 (Above 5.5)
# [5.86285714285714]
# 😆 (Above 5.5)
# [5.44]
# 😭 (Below 5.5)
# [5.649032258064514]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.623333333333334]
# 😆 (Above 5.5)
# [5.768695652173909]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.456271186440676]
# 😭 (Below 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.787428571428569]
# 😆 (Above 5.5)
# [5.595294117647059]
# 😆 (Above 5.5)
# [5.525333333333334]
# 😆 (Above 5.5)
# [5.667692307692308]
# 😆 (Above 5.5)
# [5.590399999999999]
# 😆 (Above 5.5)
# [5.404444444444443]
# 😭 (Below 5.5)
# [5.870000000000001]
# 😆 (Above 5.5)
# [5.816551724137933]
# 😆 (Above 5.5)
# [5.33]
# 😭 (Below 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.688421052631575]
# 😆 (Above 5.5)
# [5.669230769230767]
# 😆 (Above 5.5)
# [5.88363636363636]
# 😆 (Above 5.5)
# [5.798918918918915]
# 😆 (Above 5.5)
# [5.847272727272728]
# 😆 (Above 5.5)
# [5.183999999999999]
# 😭 (Below 5.5)
# [5.669565217391306]
# 😆 (Above 5.5)
# [5.919999999999999]
# 😆 (Above 5.5)
# [5.557073170731704]
# 😆 (Above 5.5)
# [5.8109090909090915]
# 😆 (Above 5.5)
# [5.4719999999999995]
# 😭 (Below 5.5)
# [5.681212121212123]
# 😆 (Above 5.5)
# [5.571428571428571]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.442962962962962]
# 😭 (Below 5.5)
# [5.763076923076923]
# 😆 (Above 5.5)
# [5.667692307692304]
# 😆 (Above 5.5)
# [5.7728]
# 😆 (Above 5.5)
# [5.782857142857145]
# 😆 (Above 5.5)
# [5.512727272727273]
# 😆 (Above 5.5)
# [4.48]
# 😭 (Below 5.5)
# [0]
# 😭 (Below 5.5)
# [5.703225806451611]
# 😆 (Above 5.5)
# [5.752727272727274]
# 😆 (Above 5.5)
# [5.810000000000001]
# 😆 (Above 5.5)
# [5.131428571428572]
# 😭 (Below 5.5)
# [5.507605633802816]
# 😆 (Above 5.5)
# [5.514285714285713]
# 😆 (Above 5.5)
# [5.8799999999999955]
# 😆 (Above 5.5)
# [5.725957446808509]
# 😆 (Above 5.5)
# [5.825263157894734]
# 😆 (Above 5.5)
# [5.651612903225807]
# 😆 (Above 5.5)
# [5.621333333333334]
# 😆 (Above 5.5)
# [5.845000000000001]
# 😆 (Above 5.5)
# [5.680000000000001]
# 😆 (Above 5.5)
# [5.6657142857142855]
# 😆 (Above 5.5)
# [5.78285714285714]
# 😆 (Above 5.5)
# [5.714285714285714]
# 😆 (Above 5.5)
# [5.831111111111111]
# 😆 (Above 5.5)
# [5.5]
# 😆 (Above 5.5)
# [5.819999999999999]
# 😆 (Above 5.5)
# [5.720000000000001]
# 😆 (Above 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.840000000000002]
# 😆 (Above 5.5)
# [5.680000000000001]
# 😆 (Above 5.5)
# [5.781818181818182]
# 😆 (Above 5.5)
# [5.489230769230766]
# 😭 (Below 5.5)
# [5.827692307692306]
# 😆 (Above 5.5)
# [5.659999999999996]
# 😆 (Above 5.5)
# [5.657560975609759]
# 😆 (Above 5.5)
# [5.549714285714287]
# 😆 (Above 5.5)
# [5.853333333333334]
# 😆 (Above 5.5)
# [5.464000000000001]
# 😭 (Below 5.5)
# [5.786666666666664]
# 😆 (Above 5.5)
# [5.104]
# 😭 (Below 5.5)
# [5.700512820512817]
# 😆 (Above 5.5)
# [5.481142857142855]
# 😭 (Below 5.5)
# [5.838840579710147]
# 😆 (Above 5.5)
# [5.679999999999998]
# 😆 (Above 5.5)
# [5.696551724137928]
# 😆 (Above 5.5)
# [5.6923076923076925]
# 😆 (Above 5.5)
# [5.600000000000002]
# 😆 (Above 5.5)
# [5.726666666666663]
# 😆 (Above 5.5)
# [5.729999999999998]
# 😆 (Above 5.5)
# [5.675076923076924]
# 😆 (Above 5.5)
# [5.632653061224489]
# 😆 (Above 5.5)
# [5.919999999999999]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.629714285714284]
# 😆 (Above 5.5)
# [5.305263157894735]
# 😭 (Below 5.5)
# [5.52]
# 😆 (Above 5.5)
# [5.56]
# 😆 (Above 5.5)
# [5.5685714285714285]
# 😆 (Above 5.5)
# [5.756097560975614]
# 😆 (Above 5.5)
# [5.788235294117644]
# 😆 (Above 5.5)
# [5.1]
# 😭 (Below 5.5)
# [5.726153846153846]
# 😆 (Above 5.5)
# [5.739047619047618]
# 😆 (Above 5.5)
# [5.641481481481482]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.700512820512817]
# 😆 (Above 5.5)
# [5.780000000000001]
# 😆 (Above 5.5)
# [5.6430769230769195]
# 😆 (Above 5.5)
# [5.800000000000002]
# 😆 (Above 5.5)
# [5.584]
# 😆 (Above 5.5)
# [5.658181818181819]
# 😆 (Above 5.5)
# [5.464575163398686]
# 😭 (Below 5.5)
# [5.699999999999997]
# 😆 (Above 5.5)
# [5.690000000000001]
# 😆 (Above 5.5)
# [5.7933333333333294]
# 😆 (Above 5.5)
# [5.774414414414409]
# 😆 (Above 5.5)
# [5.498947368421054]
# 😭 (Below 5.5)
# [5.76655737704918]
# 😆 (Above 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.413333333333334]
# 😭 (Below 5.5)
# [5.632727272727274]
# 😆 (Above 5.5)
# [5.710588235294117]
# 😆 (Above 5.5)
# [5.697499999999997]
# 😆 (Above 5.5)
# [5.539999999999999]
# 😆 (Above 5.5)
# [5.876756756756754]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.279999999999999]
# 😭 (Below 5.5)
# [5.576774193548384]
# 😆 (Above 5.5)
# [5.850847457627112]
# 😆 (Above 5.5)
# [5.6707692307692295]
# 😆 (Above 5.5)
# [5.804878048780483]
# 😆 (Above 5.5)
# [5.390769230769231]
# 😭 (Below 5.5)
# [5.696969696969694]
# 😆 (Above 5.5)
# [5.525333333333334]
# 😆 (Above 5.5)
# [5.498666666666667]
# 😭 (Below 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.724799999999999]
# 😆 (Above 5.5)
# [5.6214634146341425]
# 😆 (Above 5.5)
# [5.535609756097558]
# 😆 (Above 5.5)
# [5.669565217391306]
# 😆 (Above 5.5)
# [5.0]
# 😭 (Below 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.525714285714286]
# 😆 (Above 5.5)
# [5.395000000000001]
# 😭 (Below 5.5)
# [0]
# 😭 (Below 5.5)
# [5.691707317073169]
# 😆 (Above 5.5)
# [5.751666666666665]
# 😆 (Above 5.5)
# [5.653333333333329]
# 😆 (Above 5.5)
# [5.776842105263155]
# 😆 (Above 5.5)
# [5.6847058823529375]
# 😆 (Above 5.5)
# [5.718518518518523]
# 😆 (Above 5.5)
# [5.886666666666663]
# 😆 (Above 5.5)
# [5.464615384615384]
# 😭 (Below 5.5)
# [5.525714285714286]
# 😆 (Above 5.5)
# [5.750588235294119]
# 😆 (Above 5.5)
# [5.794594594594582]
# 😆 (Above 5.5)
# [5.84]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.828000000000001]
# 😆 (Above 5.5)
# [5.46181818181818]
# 😭 (Below 5.5)
# [5.595555555555553]
# 😆 (Above 5.5)
# [5.564444444444448]
# 😆 (Above 5.5)
# [5.755000000000001]
# 😆 (Above 5.5)
# [5.7360000000000015]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.855609756097557]
# 😆 (Above 5.5)
# [5.652307692307692]
# 😆 (Above 5.5)
# [5.708679245283015]
# 😆 (Above 5.5)
# [5.840000000000001]
# 😆 (Above 5.5)
# [5.6421052631578945]
# 😆 (Above 5.5)
# [5.6752941176470575]
# 😆 (Above 5.5)
# [5.712500000000001]
# 😆 (Above 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.655813953488372]
# 😆 (Above 5.5)
# [5.5172413793103425]
# 😆 (Above 5.5)
# [5.615999999999997]
# 😆 (Above 5.5)
# [5.7714285714285705]
# 😆 (Above 5.5)
# [5.589743589743587]
# 😆 (Above 5.5)
# [5.792592592592591]
# 😆 (Above 5.5)
# [5.91322033898305]
# 😆 (Above 5.5)
# [5.7496774193548355]
# 😆 (Above 5.5)
# [5.712857142857145]
# 😆 (Above 5.5)
# [5.774399999999996]
# 😆 (Above 5.5)
# [5.535999999999996]
# 😆 (Above 5.5)
# [5.510000000000001]
# 😆 (Above 5.5)
# [5.816774193548387]
# 😆 (Above 5.5)
# [5.840000000000001]
# 😆 (Above 5.5)
# [5.798918918918915]
# 😆 (Above 5.5)
# [5.565128205128204]
# 😆 (Above 5.5)
# [5.893333333333334]
# 😆 (Above 5.5)
# [5.842191780821921]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.669565217391306]
# 😆 (Above 5.5)
# [5.815384615384611]
# 😆 (Above 5.5)
# [5.632592592592592]
# 😆 (Above 5.5)
# [5.2]
# 😭 (Below 5.5)
# [5.3066666666666675]
# 😭 (Below 5.5)
# [5.779354838709679]
# 😆 (Above 5.5)
# [5.5767741935483865]
# 😆 (Above 5.5)
# [5.866666666666668]
# 😆 (Above 5.5)
# [5.714285714285715]
# 😆 (Above 5.5)
# [5.720000000000001]
# 😆 (Above 5.5)
# [5.64]
# 😆 (Above 5.5)
# [5.872941176470589]
# 😆 (Above 5.5)
# [5.862857142857144]
# 😆 (Above 5.5)
# [5.73037037037037]
# 😆 (Above 5.5)
# [5.8799999999999955]
# 😆 (Above 5.5)
# [5.8568421052631585]
# 😆 (Above 5.5)
# [5.359999999999999]
# 😭 (Below 5.5)
# [5.674666666666665]
# 😆 (Above 5.5)
# [5.526153846153846]
# 😆 (Above 5.5)
# [5.762388059701496]
# 😆 (Above 5.5)
# [5.719999999999999]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.767619047619047]
# 😆 (Above 5.5)
# [5.664516129032256]
# 😆 (Above 5.5)
# [5.830243902439019]
# 😆 (Above 5.5)
# [5.718666666666667]
# 😆 (Above 5.5)
# [5.754285714285709]
# 😆 (Above 5.5)
# [5.497142857142857]
# 😭 (Below 5.5)
# [5.71428571428571]
# 😆 (Above 5.5)
# [5.799183673469384]
# 😆 (Above 5.5)
# [5.742608695652169]
# 😆 (Above 5.5)
# [5.711999999999998]
# 😆 (Above 5.5)
# [5.660408163265302]
# 😆 (Above 5.5)
# [5.737777777777774]
# 😆 (Above 5.5)
# [5.769756097560971]
# 😆 (Above 5.5)
# [5.666086956521734]
# 😆 (Above 5.5)
# [5.643636363636364]
# 😆 (Above 5.5)
# [5.676279069767437]
# 😆 (Above 5.5)
# [5.883636363636365]
# 😆 (Above 5.5)
# [5.667200000000001]
# 😆 (Above 5.5)
# [5.736585365853655]
# 😆 (Above 5.5)
# [5.757499999999999]
# 😆 (Above 5.5)
# [5.353846153846154]
# 😭 (Below 5.5)
# [5.726222222222218]
# 😆 (Above 5.5)
# [5.7457142857142856]
# 😆 (Above 5.5)
# [5.716363636363634]
# 😆 (Above 5.5)
# [5.656969696969698]
# 😆 (Above 5.5)
# [5.166666666666668]
# 😭 (Below 5.5)
# [5.72923076923077]
# 😆 (Above 5.5)
# [5.792592592592591]
# 😆 (Above 5.5)
# [5.867826086956522]
# 😆 (Above 5.5)
# [5.571764705882353]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.831794871794867]
# 😆 (Above 5.5)
# [5.504]
# 😆 (Above 5.5)
# [5.683636363636366]
# 😆 (Above 5.5)
# [5.572765957446808]
# 😆 (Above 5.5)
# [5.757647058823527]
# 😆 (Above 5.5)
# [5.4819047619047625]
# 😭 (Below 5.5)
# [5.880000000000001]
# 😆 (Above 5.5)
# [5.57767441860465]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.786666666666666]
# 😆 (Above 5.5)
# [5.475]
# 😭 (Below 5.5)
# [5.77]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.4997333333333325]
# 😭 (Below 5.5)
# [5.696]
# 😆 (Above 5.5)
# [5.857777777777773]
# 😆 (Above 5.5)
# [5.59709090909091]
# 😆 (Above 5.5)
# [5.626666666666665]
# 😆 (Above 5.5)
# [5.691076923076925]
# 😆 (Above 5.5)
# [5.70201834862385]
# 😆 (Above 5.5)
# [5.77142857142857]
# 😆 (Above 5.5)
# [5.4027906976744156]
# 😭 (Below 5.5)
# [5.4719999999999995]
# 😭 (Below 5.5)
# [5.497777777777779]
# 😭 (Below 5.5)
# [5.877894736842106]
# 😆 (Above 5.5)
# [5.482666666666668]
# 😭 (Below 5.5)
# [5.540000000000001]
# 😆 (Above 5.5)
# [5.390588235294116]
# 😭 (Below 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.806956521739127]
# 😆 (Above 5.5)
# [5.617777777777778]
# 😆 (Above 5.5)
# [5.815384615384611]
# 😆 (Above 5.5)
# [4.48]
# 😭 (Below 5.5)
# [5.761212121212122]
# 😆 (Above 5.5)
# [5.701818181818181]
# 😆 (Above 5.5)
# [5.767547169811317]
# 😆 (Above 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.6061538461538465]
# 😆 (Above 5.5)
# [5.815757575757578]
# 😆 (Above 5.5)
# [5.456842105263158]
# 😭 (Below 5.5)
# [5.368]
# 😭 (Below 5.5)
# [5.685714285714286]
# 😆 (Above 5.5)
# [5.711111111111107]
# 😆 (Above 5.5)
# [5.628717948717948]
# 😆 (Above 5.5)
# [5.64]
# 😆 (Above 5.5)
# [5.707692307692308]
# 😆 (Above 5.5)
# [5.682666666666665]
# 😆 (Above 5.5)
# [5.92]
# 😆 (Above 5.5)
# [5.6316279069767425]
# 😆 (Above 5.5)
# [5.511111111111112]
# 😆 (Above 5.5)
# [5.563428571428569]
# 😆 (Above 5.5)
# [5.734237288135593]
# 😆 (Above 5.5)
# [0]
# 😭 (Below 5.5)
# [5.8464]
# 😆 (Above 5.5)
# [5.840000000000001]
# 😆 (Above 5.5)
# [5.52]
# 😆 (Above 5.5)
# [5.510000000000001]
# 😆 (Above 5.5)
# [5.53]
# 😆 (Above 5.5)
# [5.776000000000002]
# 😆 (Above 5.5)
# [5.734358974358977]
# 😆 (Above 5.5)
# [5.72]
# 😆 (Above 5.5)
# [5.83111111111111]
# 😆 (Above 5.5)
# [5.7579999999999965]
# 😆 (Above 5.5)
# [5.485]
# 😭 (Below 5.5)
# [5.524705882352941]
# 😆 (Above 5.5)
# [5.751489361702124]
# 😆 (Above 5.5)
# [5.74915254237288]
# 😆 (Above 5.5)
# [5.688275862068964]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.847272727272728]
# 😆 (Above 5.5)
# [5.792592592592591]
# 😆 (Above 5.5)
# [5.707826086956521]
# 😆 (Above 5.5)
# [5.173333333333333]
# 😭 (Below 5.5)
# [5.82]
# 😆 (Above 5.5)
# [5.853333333333334]
# 😆 (Above 5.5)
# [5.840000000000002]
# 😆 (Above 5.5)
# [5.832500000000001]
# 😆 (Above 5.5)
# [5.349565217391306]
# 😭 (Below 5.5)
# [5.489999999999999]
# 😭 (Below 5.5)
# [5.526153846153846]
# 😆 (Above 5.5)
# [5.760000000000001]
# 😆 (Above 5.5)
# [5.416470588235295]
# 😭 (Below 5.5)
# [5.862857142857143]
# 😆 (Above 5.5)
# [5.501538461538461]
# 😆 (Above 5.5)
# [5.655384615384615]
# 😆 (Above 5.5)
# [5.8755555555555565]
# 😆 (Above 5.5)
# [5.737142857142856]
# 😆 (Above 5.5)
# [5.687466666666668]
# 😆 (Above 5.5)
# [5.742499999999999]
# 😆 (Above 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.59230769230769]
# 😆 (Above 5.5)
# [5.742857142857147]
# 😆 (Above 5.5)
# [5.333333333333333]
# 😭 (Below 5.5)
# [5.590000000000001]
# 😆 (Above 5.5)
# [5.4871794871794854]
# 😭 (Below 5.5)
# [5.662608695652171]
# 😆 (Above 5.5)
# [5.338947368421053]
# 😭 (Below 5.5)
# [5.716363636363638]
# 😆 (Above 5.5)
# [5.78461538461538]
# 😆 (Above 5.5)
# [5.630476190476191]
# 😆 (Above 5.5)
# [5.690256410256406]
# 😆 (Above 5.5)
# [5.830329670329674]
# 😆 (Above 5.5)
# [5.684848484848481]
# 😆 (Above 5.5)
# [5.768275862068966]
# 😆 (Above 5.5)
# [5.7294545454545425]
# 😆 (Above 5.5)
# [5.566197183098592]
# 😆 (Above 5.5)
# [5.7253012048192815]
# 😆 (Above 5.5)
# [5.849999999999997]
# 😆 (Above 5.5)
# [5.6000000000000005]
# 😆 (Above 5.5)
# [5.865454545454546]
# 😆 (Above 5.5)
# [5.4799999999999995]
# 😭 (Below 5.5)
# [5.632676056338029]
# 😆 (Above 5.5)
# [5.418181818181814]
# 😭 (Below 5.5)
# [5.2705882352941185]
# 😭 (Below 5.5)
# [5.5858823529411765]
# 😆 (Above 5.5)
# [5.565866666666668]
# 😆 (Above 5.5)
# [5.689696969696967]
# 😆 (Above 5.5)
# [5.8299999999999965]
# 😆 (Above 5.5)
# [5.571764705882352]
# 😆 (Above 5.5)
# [5.6138666666666674]
# 😆 (Above 5.5)
# [5.495384615384615]
# 😭 (Below 5.5)
# [5.787692307692307]
# 😆 (Above 5.5)
# [5.497499999999998]
# 😭 (Below 5.5)
# [5.760000000000001]
# 😆 (Above 5.5)
# [5.493333333333332]
# 😭 (Below 5.5)
# [5.920000000000001]
# 😆 (Above 5.5)
# [5.779692307692309]
# 😆 (Above 5.5)
# [5.770909090909092]
# 😆 (Above 5.5)
# [5.734054054054051]
# 😆 (Above 5.5)
# [5.695999999999999]
# 😆 (Above 5.5)
# [5.556078431372547]
# 😆 (Above 5.5)
# [5.487058823529413]
# 😭 (Below 5.5)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 import pandas as pd
#       5 # Mastodon
# ----> 6 mastodon_retrieve.streaming_mastodon()
#
# File ~/Documents/GitHub/social-media-analytics-on-cloud/script/mastodon_retrieve.py:41, in streaming_mastodon()
#      36     cfg = yaml.load(f, Loader=yaml.FullLoader)
#      37     m = Mastodon(
#      38         api_base_url=f"https://mastodon.au",
#      39         access_token=cfg["MASTODON_ACCESS_TOKEN"],
#      40     )
# ---> 41     m.stream_public(Listener())
#      42 return None
#
# File ~/miniconda3/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/Documents/GitHub/social-media-analytics-on-cloud/script/mastodon/utility.py:49, in api_version.<locals>.api_min_version_decorator.<locals>.wrapper(function, self, *args, **kwargs)
#      47     elif major == self.mastodon_major and minor == self.mastodon_minor and patch > self.mastodon_patch:
#      48         raise MastodonVersionError(f"Version check failed (Need version {version}, patch is {self.mastodon_patch})")
# ---> 49 return function(self, *args, **kwargs)
#
# File ~/Documents/GitHub/social-media-analytics-on-cloud/script/mastodon/streaming_endpoints.py:38, in Mastodon.stream_public(self, listener, run_async, timeout, reconnect_async, reconnect_async_wait_sec, local, remote)
#      36         raise MastodonIllegalArgumentError("Cannot pass both local and remote - use either one or the other.")
#      37     base += '/remote'
# ---> 38 return self.__stream(base, listener, run_async=run_async, timeout=timeout, reconnect_async=reconnect_async, reconnect_async_wait_sec=reconnect_async_wait_sec)
#
# File ~/Documents/GitHub/social-media-analytics-on-cloud/script/mastodon/internals.py:540, in Mastodon.__stream(self, endpoint, listener, params, run_async, timeout, reconnect_async, reconnect_async_wait_sec)
#     538 connection = connect_func()
#     539 with closing(connection) as r:
# --> 540     listener.handle_stream(r)
#
# File ~/Documents/GitHub/social-media-analytics-on-cloud/script/mastodon/streaming.py:109, in StreamListener.handle_stream(self, response)
#     107 line_buffer = bytearray()
#     108 try:
# --> 109     for chunk in response.iter_content(chunk_size=1):
#     110         if chunk:
#     111             for chunk_part in chunk:
#
# File ~/miniconda3/lib/python3.9/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/lib/python3.9/site-packages/urllib3/response.py:575, in HTTPResponse.stream(self, amt, decode_content)
#     559 """
#     560 A generator wrapper for the read() method. A call will block until
#     561 ``amt`` bytes have been read from the connection or until the
#    (...)
#     572     'content-encoding' header.
#     573 """
#     574 if self.chunked and self.supports_chunked_reads():
# --> 575     for line in self.read_chunked(amt, decode_content=decode_content):
#     576         yield line
#     577 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/urllib3/response.py:767, in HTTPResponse.read_chunked(self, amt, decode_content)
#     764     return
#     766 while True:
# --> 767     self._update_chunk_length()
#     768     if self.chunk_left == 0:
#     769         break
#
# File ~/miniconda3/lib/python3.9/site-packages/urllib3/response.py:697, in HTTPResponse._update_chunk_length(self)
#     695 if self.chunk_left is not None:
#     696     return
# --> 697 line = self._fp.fp.readline()
#     698 line = line.split(b";", 1)[0]
#     699 try:
#
# File ~/miniconda3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/miniconda3/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("../data/raw/mastodon.csv")
df
# Out:
#                                              content  \
# 0  <p>Today&#39;s turnover at <a href="https://ma...
# 1  <p>Aumentano le esportazioni italiane verso la...
# 2  <p>Awww look at these parrots:</p><p><a href="...
# 3  <p>Russian losses, 24 Feb 2022 to 9 May 2023:<...
# 4  <p>In Florida wird es immer schöner. 🤬 </p><p>...
# 5  <p>Lansdowne Park. <br>We can do better. <br>🖌...
# 6  <p>Don’t confuse kindness for weakness, kind p...
#
#                          created_at                           hashtags  \
# 0  2023-05-09 13:13:42.294000+00:00  ['judo', 'newaza', 'judojourney']
# 1         2023-05-09 12:46:21+00:00                                 []
# 2         2023-05-09 13:13:43+00:00           ['parrots', 'videocall']
# 3         2023-05-09 13:13:40+00:00                                 []
# 4         2023-05-09 13:13:46+00:00                                 []
# 5         2023-05-09 13:13:47+00:00                         ['ottawa']
# 6         2023-05-09 13:13:53+00:00                                 []
#
#   language   t_score
# 0       en  5.493333
# 1       it  5.850435
# 2       en  5.690000
# 3       en  5.580000
# 4       de  5.773333
# 5       en  5.725217
# 6       en  5.410000
